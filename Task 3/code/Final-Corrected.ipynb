# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
# mpld3.enable_notebook()

# %%
file=open("kalmann.txt",'r')
pos=np.loadtxt("kalmann.txt",delimiter=',',usecols=[0,1])
vel=np.loadtxt("kalmann.txt",skiprows=1,delimiter=',',usecols=[2,3])
vel=np.insert(vel,[0],0,axis=0)

# %%
# defining varibles
del_t=0.075
sigma_ax=0.03
sigma_ay=0.02
sigma_x=0.1
sigma_y=0.1
sigma_vx=5
sigma_vy=5
pos_x0,pos_y0=pos[0]
p=1000

# %%
pred_state=[]
est_state=[]
pred_p=[]
est_p=[]

# %%
F=np.zeros((6,6))
F[0,:3]=(1,del_t,0.5*del_t**2)
F[1,:3]=(0,1,del_t)
F[2,2]=1
F[3,3:6]=(1,del_t,0.5*del_t**2)
F[4,3:6]=(0,1,del_t)
F[5,5]=1
FT=np.transpose(F)
# F

# %%
# Q=np.zeros((6,6))
# Q[0,:3]=(0.05*del_t**5*sigma_ax**2,0.125*del_t**4*sigma_ax**2,(1/6)*del_t**3*sigma_ax**2)
# Q[1,:3]=(0,(1/3)*del_t**3*sigma_ax**2,0.5*del_t**2*sigma_ax**2)
# Q[2,:3]=(0,0,1*sigma_ax**2*del_t)
# Q[3,3:6]=(0.05*del_t**5*sigma_ay**2,0.125*del_t**4*sigma_ay**2,(1/6)*del_t**3*sigma_ay**2)
# Q[4,3:6]=(0,(1/3)*del_t**3*sigma_ay**2,0.5*del_t**2*sigma_ay**2)
# Q[5,3:6]=(0,0,1*sigma_ay**2*del_t)
# # Q=Q*sigma_ay**2
# # Q-Continuos noise

# %%
Q=np.zeros((6,6))
Q[0,:3]=(0.25*del_t**4*sigma_ax**2,0.5*del_t**3*sigma_ax**2,0.5*del_t**2*sigma_ax**2)
Q[1,:3]=(0,del_t**2*sigma_ax**2,del_t*sigma_ax**2)
Q[2,:3]=(0,0,1*sigma_ax**2)
Q[3,3:6]=(0.25*del_t**4*sigma_ay**2,0.5*del_t**3*sigma_ay**2,0.5*del_t**2*sigma_ay**2)
Q[4,3:6]=(0,del_t**2*sigma_ay**2,del_t*sigma_ay**2)
Q[5,3:6]=(0,0,1*sigma_ay**2)
# Q=Q*sigma_ay**2
# Q-Discrete noise

# %%
R=np.zeros((4,4))
R[0,0],R[1,1],R[2,2],R[3,3]=(sigma_x**2,sigma_vx**2,sigma_y**2,sigma_vy**2)
# R

# %%
H=np.zeros((4,6))
H[0,0],H[1,1],H[2,3],H[3,4] =(1,1,1,1)
HT=np.transpose(H)
# H

# %%
temp=np.zeros((6,1))
temp[:,0]=[pos_x0,0,0,pos_y0,0,0]
est_state.append(temp)
# est_state[0]

# %%
temp=np.diag((p,p,p,p,p,p))
est_p.append(temp)
# est_p[0]

# %%
def state_extrapolate(xn):
    xnext=np.dot(F,xn)
    return xnext

# %%
def cov_extrapolate(pn):
    pnext=np.dot(np.dot(F,pn),FT) +Q
    return pnext

# %%
def measure(n):
    z=np.zeros((4,1))
    z[:,0]=(pos[n,0],vel[n,0],pos[n,1],vel[n,1])
    return z

# %%
def K_gain(n):
    kn=np.dot(np.dot(pred_p[n-1],HT),(np.linalg.inv(np.dot(np.dot(H,pred_p[n-1]),HT)+R)))
    return kn

# %%
def state_update(xn_1,kn,zn):
    xn=xn_1 + np.dot(kn,(zn-np.dot(H,xn_1)))
    return xn

# %%
def cov_update(pn_1,kn):
    idm=(np.identity(6)-np.dot(kn,H))
    idmT=np.transpose(idm)
    pn=np.dot(np.dot(idm,pn_1),idmT)+ np.dot(np.dot(kn,R),np.transpose(kn))
    return pn

# %%
pred_state.append(state_extrapolate(est_state[0]))
pred_p.append(cov_extrapolate(est_p[0]))
for i in range(1,len(vel)):
    print("\n---------------------------------\n\nIteration :-",i)
    zi=measure(i)
    ki=K_gain(i)
    est_state.append(state_update(pred_state[i-1],ki,zi))
    print("Estimated position(x,y) :- (%g,%g)" % (est_state[i][0],est_state[i][3]))
    est_p.append(cov_update(pred_p[i-1],ki))
    pred_state.append(state_extrapolate(est_state[i]))
    print("Uncertainity(x,y) :- (%g,%g)" % (est_p[i][0,0],est_p[i][3,3]))
    pred_p.append(cov_extrapolate(est_p[i]))
# Out:
# ---------------------------------
#
# Iteration :- 1
# Estimated position(x,y) :- (368.189,6.59655)
# Uncertainity(x,y) :- (0.0099999,0.0099999)
#
# ---------------------------------
#
# Iteration :- 2
# Estimated position(x,y) :- (369.359,12.0599)
# Uncertainity(x,y) :- (0.00888206,0.00888206)
#
# ---------------------------------
#
# Iteration :- 3
# Estimated position(x,y) :- (375.865,19.0801)
# Uncertainity(x,y) :- (0.00829578,0.00829578)
#
# ---------------------------------
#
# Iteration :- 4
# Estimated position(x,y) :- (368.223,25.3153)
# Uncertainity(x,y) :- (0.00824954,0.00824954)
#
# ---------------------------------
#
# Iteration :- 5
# Estimated position(x,y) :- (368.665,31.6854)
# Uncertainity(x,y) :- (0.00806763,0.00806763)
#
# ---------------------------------
#
# Iteration :- 6
# Estimated position(x,y) :- (369.417,38.6242)
# Uncertainity(x,y) :- (0.00770016,0.00770016)
#
# ---------------------------------
#
# Iteration :- 7
# Estimated position(x,y) :- (368.111,44.9714)
# Uncertainity(x,y) :- (0.00726643,0.00726642)
#
# ---------------------------------
#
# Iteration :- 8
# Estimated position(x,y) :- (364.807,51.0021)
# Uncertainity(x,y) :- (0.00683048,0.00683047)
#
# ---------------------------------
#
# Iteration :- 9
# Estimated position(x,y) :- (360.34,56.9816)
# Uncertainity(x,y) :- (0.00641822,0.0064182)
#
# ---------------------------------
#
# Iteration :- 10
# Estimated position(x,y) :- (353.459,63.6217)
# Uncertainity(x,y) :- (0.00603829,0.00603824)
#
# ---------------------------------
#
# Iteration :- 11
# Estimated position(x,y) :- (352.461,70.2135)
# Uncertainity(x,y) :- (0.00569201,0.00569192)
#
# ---------------------------------
#
# Iteration :- 12
# Estimated position(x,y) :- (351.86,76.5541)
# Uncertainity(x,y) :- (0.00537771,0.00537756)
#
# ---------------------------------
#
# Iteration :- 13
# Estimated position(x,y) :- (349.482,81.6197)
# Uncertainity(x,y) :- (0.00509265,0.0050924)
#
# ---------------------------------
#
# Iteration :- 14
# Estimated position(x,y) :- (349.224,88.071)
# Uncertainity(x,y) :- (0.00483385,0.00483346)
#
# ---------------------------------
#
# Iteration :- 15
# Estimated position(x,y) :- (344.942,94.0776)
# Uncertainity(x,y) :- (0.00459842,0.00459783)
#
# ---------------------------------
#
# Iteration :- 16
# Estimated position(x,y) :- (342.595,99.117)
# Uncertainity(x,y) :- (0.00438375,0.0043829)
#
# ---------------------------------
#
# Iteration :- 17
# Estimated position(x,y) :- (340.146,105)
# Uncertainity(x,y) :- (0.00418751,0.00418631)
#
# ---------------------------------
#
# Iteration :- 18
# Estimated position(x,y) :- (336.552,110.323)
# Uncertainity(x,y) :- (0.00400768,0.00400602)
#
# ---------------------------------
#
# Iteration :- 19
# Estimated position(x,y) :- (333.675,115.842)
# Uncertainity(x,y) :- (0.00384249,0.00384023)
#
# ---------------------------------
#
# Iteration :- 20
# Estimated position(x,y) :- (330.93,120.423)
# Uncertainity(x,y) :- (0.00369042,0.0036874)
#
# ---------------------------------
#
# Iteration :- 21
# Estimated position(x,y) :- (329.046,125.98)
# Uncertainity(x,y) :- (0.00355014,0.00354619)
#
# ---------------------------------
#
# Iteration :- 22
# Estimated position(x,y) :- (326.819,130.4)
# Uncertainity(x,y) :- (0.00342053,0.00341542)
#
# ---------------------------------
#
# Iteration :- 23
# Estimated position(x,y) :- (324.135,135.843)
# Uncertainity(x,y) :- (0.00330062,0.00329409)
#
# ---------------------------------
#
# Iteration :- 24
# Estimated position(x,y) :- (319.872,140.801)
# Uncertainity(x,y) :- (0.00318955,0.00318132)
#
# ---------------------------------
#
# Iteration :- 25
# Estimated position(x,y) :- (316.532,146.117)
# Uncertainity(x,y) :- (0.00308661,0.00307634)
#
# ---------------------------------
#
# Iteration :- 26
# Estimated position(x,y) :- (311.261,150.765)
# Uncertainity(x,y) :- (0.00299118,0.0029785)
#
# ---------------------------------
#
# Iteration :- 27
# Estimated position(x,y) :- (306.532,155.903)
# Uncertainity(x,y) :- (0.00290271,0.0028872)
#
# ---------------------------------
#
# Iteration :- 28
# Estimated position(x,y) :- (301.952,160.643)
# Uncertainity(x,y) :- (0.00282074,0.00280195)
#
# ---------------------------------
#
# Iteration :- 29
# Estimated position(x,y) :- (297.422,165.07)
# Uncertainity(x,y) :- (0.00274487,0.0027223)
#
# ---------------------------------
#
# Iteration :- 30
# Estimated position(x,y) :- (292.454,169.371)
# Uncertainity(x,y) :- (0.00267477,0.00264788)
#
# ---------------------------------
#
# Iteration :- 31
# Estimated position(x,y) :- (287.806,175.226)
# Uncertainity(x,y) :- (0.00261012,0.00257833)
#
# ---------------------------------
#
# Iteration :- 32
# Estimated position(x,y) :- (282.201,180.228)
# Uncertainity(x,y) :- (0.00255067,0.00251337)
#
# ---------------------------------
#
# Iteration :- 33
# Estimated position(x,y) :- (279.13,183.475)
# Uncertainity(x,y) :- (0.00249617,0.00245273)
#
# ---------------------------------
#
# Iteration :- 34
# Estimated position(x,y) :- (274.44,187.511)
# Uncertainity(x,y) :- (0.00244642,0.0023962)
#
# ---------------------------------
#
# Iteration :- 35
# Estimated position(x,y) :- (269.785,190.849)
# Uncertainity(x,y) :- (0.00240122,0.00234356)
#
# ---------------------------------
#
# Iteration :- 36
# Estimated position(x,y) :- (266.541,194.898)
# Uncertainity(x,y) :- (0.00236037,0.00229464)
#
# ---------------------------------
#
# Iteration :- 37
# Estimated position(x,y) :- (262.566,199.128)
# Uncertainity(x,y) :- (0.0023237,0.00224928)
#
# ---------------------------------
#
# Iteration :- 38
# Estimated position(x,y) :- (257.989,202.338)
# Uncertainity(x,y) :- (0.00229102,0.00220733)
#
# ---------------------------------
#
# Iteration :- 39
# Estimated position(x,y) :- (252.525,206.279)
# Uncertainity(x,y) :- (0.00226212,0.00216866)
#
# ---------------------------------
#
# Iteration :- 40
# Estimated position(x,y) :- (247.491,209.168)
# Uncertainity(x,y) :- (0.00223682,0.00213314)
#
# ---------------------------------
#
# Iteration :- 41
# Estimated position(x,y) :- (242.239,212.665)
# Uncertainity(x,y) :- (0.00221488,0.00210066)
#
# ---------------------------------
#
# Iteration :- 42
# Estimated position(x,y) :- (237.557,216.566)
# Uncertainity(x,y) :- (0.00219609,0.00207109)
#
# ---------------------------------
#
# Iteration :- 43
# Estimated position(x,y) :- (232.626,218.978)
# Uncertainity(x,y) :- (0.00218021,0.00204432)
#
# ---------------------------------
#
# Iteration :- 44
# Estimated position(x,y) :- (227.557,222.234)
# Uncertainity(x,y) :- (0.00216697,0.00202023)
#
# ---------------------------------
#
# Iteration :- 45
# Estimated position(x,y) :- (222.28,225.109)
# Uncertainity(x,y) :- (0.00215613,0.00199869)
#
# ---------------------------------
#
# Iteration :- 46
# Estimated position(x,y) :- (217.053,228.388)
# Uncertainity(x,y) :- (0.00214741,0.00197958)
#
# ---------------------------------
#
# Iteration :- 47
# Estimated position(x,y) :- (211.581,231.31)
# Uncertainity(x,y) :- (0.00214054,0.00196276)
#
# ---------------------------------
#
# Iteration :- 48
# Estimated position(x,y) :- (205.876,233.915)
# Uncertainity(x,y) :- (0.00213527,0.0019481)
#
# ---------------------------------
#
# Iteration :- 49
# Estimated position(x,y) :- (200.64,235.978)
# Uncertainity(x,y) :- (0.00213135,0.00193543)
#
# ---------------------------------
#
# Iteration :- 50
# Estimated position(x,y) :- (195.335,238.524)
# Uncertainity(x,y) :- (0.00212852,0.00192462)
#
# ---------------------------------
#
# Iteration :- 51
# Estimated position(x,y) :- (190.179,240.077)
# Uncertainity(x,y) :- (0.00212658,0.0019155)
#
# ---------------------------------
#
# Iteration :- 52
# Estimated position(x,y) :- (184.931,242.392)
# Uncertainity(x,y) :- (0.00212531,0.00190791)
#
# ---------------------------------
#
# Iteration :- 53
# Estimated position(x,y) :- (180.114,244.193)
# Uncertainity(x,y) :- (0.00212456,0.00190169)
#
# ---------------------------------
#
# Iteration :- 54
# Estimated position(x,y) :- (174.832,246.037)
# Uncertainity(x,y) :- (0.00212416,0.00189669)
#
# ---------------------------------
#
# Iteration :- 55
# Estimated position(x,y) :- (169.824,247.251)
# Uncertainity(x,y) :- (0.00212399,0.00189274)
#
# ---------------------------------
#
# Iteration :- 56
# Estimated position(x,y) :- (164.908,249.059)
# Uncertainity(x,y) :- (0.00212395,0.00188969)
#
# ---------------------------------
#
# Iteration :- 57
# Estimated position(x,y) :- (160.344,251.721)
# Uncertainity(x,y) :- (0.00212396,0.00188741)
#
# ---------------------------------
#
# Iteration :- 58
# Estimated position(x,y) :- (155.856,252.42)
# Uncertainity(x,y) :- (0.00212397,0.00188575)
#
# ---------------------------------
#
# Iteration :- 59
# Estimated position(x,y) :- (150.798,254.851)
# Uncertainity(x,y) :- (0.00212393,0.0018846)
#
# ---------------------------------
#
# Iteration :- 60
# Estimated position(x,y) :- (145.751,255.734)
# Uncertainity(x,y) :- (0.00212383,0.00188383)
#
# ---------------------------------
#
# Iteration :- 61
# Estimated position(x,y) :- (140.461,257.284)
# Uncertainity(x,y) :- (0.00212366,0.00188337)
#
# ---------------------------------
#
# Iteration :- 62
# Estimated position(x,y) :- (136.3,258.555)
# Uncertainity(x,y) :- (0.0021234,0.00188311)
#
# ---------------------------------
#
# Iteration :- 63
# Estimated position(x,y) :- (131.479,260.93)
# Uncertainity(x,y) :- (0.00212308,0.001883)
#
# ---------------------------------
#
# Iteration :- 64
# Estimated position(x,y) :- (126.3,261.602)
# Uncertainity(x,y) :- (0.0021227,0.00188297)
#
# ---------------------------------
#
# Iteration :- 65
# Estimated position(x,y) :- (121.28,262.465)
# Uncertainity(x,y) :- (0.00212228,0.00188297)
#
# ---------------------------------
#
# Iteration :- 66
# Estimated position(x,y) :- (116.383,263.801)
# Uncertainity(x,y) :- (0.00212182,0.00188298)
#
# ---------------------------------
#
# Iteration :- 67
# Estimated position(x,y) :- (111.892,264.762)
# Uncertainity(x,y) :- (0.00212136,0.00188296)
#
# ---------------------------------
#
# Iteration :- 68
# Estimated position(x,y) :- (106.855,264.673)
# Uncertainity(x,y) :- (0.0021209,0.00188291)
#
# ---------------------------------
#
# Iteration :- 69
# Estimated position(x,y) :- (102.179,265.858)
# Uncertainity(x,y) :- (0.00212045,0.0018828)
#
# ---------------------------------
#
# Iteration :- 70
# Estimated position(x,y) :- (97.323,267.343)
# Uncertainity(x,y) :- (0.00212002,0.00188264)
#
# ---------------------------------
#
# Iteration :- 71
# Estimated position(x,y) :- (92.5532,268.177)
# Uncertainity(x,y) :- (0.00211963,0.00188243)
#
# ---------------------------------
#
# Iteration :- 72
# Estimated position(x,y) :- (87.7594,268.757)
# Uncertainity(x,y) :- (0.00211928,0.00188217)
#
# ---------------------------------
#
# Iteration :- 73
# Estimated position(x,y) :- (83.0246,269.418)
# Uncertainity(x,y) :- (0.00211897,0.00188187)
#
# ---------------------------------
#
# Iteration :- 74
# Estimated position(x,y) :- (78.1987,270.007)
# Uncertainity(x,y) :- (0.0021187,0.00188154)
#
# ---------------------------------
#
# Iteration :- 75
# Estimated position(x,y) :- (73.1919,271.936)
# Uncertainity(x,y) :- (0.00211847,0.00188118)
#
# ---------------------------------
#
# Iteration :- 76
# Estimated position(x,y) :- (68.6798,271.614)
# Uncertainity(x,y) :- (0.00211829,0.00188082)
#
# ---------------------------------
#
# Iteration :- 77
# Estimated position(x,y) :- (63.9484,272.225)
# Uncertainity(x,y) :- (0.00211814,0.00188045)
#
# ---------------------------------
#
# Iteration :- 78
# Estimated position(x,y) :- (58.9982,273.457)
# Uncertainity(x,y) :- (0.00211802,0.00188008)
#
# ---------------------------------
#
# Iteration :- 79
# Estimated position(x,y) :- (54.1626,274.5)
# Uncertainity(x,y) :- (0.00211793,0.00187973)
#
# ---------------------------------
#
# Iteration :- 80
# Estimated position(x,y) :- (49.4213,275.323)
# Uncertainity(x,y) :- (0.00211787,0.00187939)
#
# ---------------------------------
#
# Iteration :- 81
# Estimated position(x,y) :- (44.6035,275.112)
# Uncertainity(x,y) :- (0.00211782,0.00187908)
#
# ---------------------------------
#
# Iteration :- 82
# Estimated position(x,y) :- (39.6659,275.536)
# Uncertainity(x,y) :- (0.0021178,0.00187879)
#
# ---------------------------------
#
# Iteration :- 83
# Estimated position(x,y) :- (34.7928,275.093)
# Uncertainity(x,y) :- (0.00211778,0.00187853)
#
# ---------------------------------
#
# Iteration :- 84
# Estimated position(x,y) :- (30.077,276.525)
# Uncertainity(x,y) :- (0.00211777,0.0018783)
#
# ---------------------------------
#
# Iteration :- 85
# Estimated position(x,y) :- (25.1433,278.446)
# Uncertainity(x,y) :- (0.00211777,0.0018781)
#
# ---------------------------------
#
# Iteration :- 86
# Estimated position(x,y) :- (20.2824,278.215)
# Uncertainity(x,y) :- (0.00211777,0.00187793)
#
# ---------------------------------
#
# Iteration :- 87
# Estimated position(x,y) :- (15.3339,277.608)
# Uncertainity(x,y) :- (0.00211777,0.00187778)
#
# ---------------------------------
#
# Iteration :- 88
# Estimated position(x,y) :- (10.434,278.001)
# Uncertainity(x,y) :- (0.00211777,0.00187767)
#
# ---------------------------------
#
# Iteration :- 89
# Estimated position(x,y) :- (5.52156,278.547)
# Uncertainity(x,y) :- (0.00211777,0.00187757)
#
# ---------------------------------
#
# Iteration :- 90
# Estimated position(x,y) :- (0.526064,278.849)
# Uncertainity(x,y) :- (0.00211777,0.0018775)
#
# ---------------------------------
#
# Iteration :- 91
# Estimated position(x,y) :- (-4.38607,279.775)
# Uncertainity(x,y) :- (0.00211776,0.00187744)
#
# ---------------------------------
#
# Iteration :- 92
# Estimated position(x,y) :- (-9.26397,279.7)
# Uncertainity(x,y) :- (0.00211776,0.0018774)
#
# ---------------------------------
#
# Iteration :- 93
# Estimated position(x,y) :- (-14.1445,279.882)
# Uncertainity(x,y) :- (0.00211775,0.00187737)
#
# ---------------------------------
#
# Iteration :- 94
# Estimated position(x,y) :- (-19.0874,280.424)
# Uncertainity(x,y) :- (0.00211774,0.00187735)
#
# ---------------------------------
#
# Iteration :- 95
# Estimated position(x,y) :- (-23.9358,279.706)
# Uncertainity(x,y) :- (0.00211773,0.00187733)
#
# ---------------------------------
#
# Iteration :- 96
# Estimated position(x,y) :- (-28.8199,278.65)
# Uncertainity(x,y) :- (0.00211771,0.00187733)
#
# ---------------------------------
#
# Iteration :- 97
# Estimated position(x,y) :- (-33.6823,278.298)
# Uncertainity(x,y) :- (0.0021177,0.00187732)
#
# ---------------------------------
#
# Iteration :- 98
# Estimated position(x,y) :- (-38.5515,278.245)
# Uncertainity(x,y) :- (0.00211769,0.00187732)
#
# ---------------------------------
#
# Iteration :- 99
# Estimated position(x,y) :- (-43.5075,277.266)
# Uncertainity(x,y) :- (0.00211768,0.00187732)
#
# ---------------------------------
#
# Iteration :- 100
# Estimated position(x,y) :- (-48.2664,276.63)
# Uncertainity(x,y) :- (0.00211766,0.00187732)
#
# ---------------------------------
#
# Iteration :- 101
# Estimated position(x,y) :- (-53.4714,275.581)
# Uncertainity(x,y) :- (0.00211765,0.00187732)
#
# ---------------------------------
#
# Iteration :- 102
# Estimated position(x,y) :- (-58.3554,274.453)
# Uncertainity(x,y) :- (0.00211764,0.00187732)
#
# ---------------------------------
#
# Iteration :- 103
# Estimated position(x,y) :- (-63.0212,274.101)
# Uncertainity(x,y) :- (0.00211763,0.00187732)
#
# ---------------------------------
#
# Iteration :- 104
# Estimated position(x,y) :- (-67.8329,273.614)
# Uncertainity(x,y) :- (0.00211763,0.00187732)
#
# ---------------------------------
#
# Iteration :- 105
# Estimated position(x,y) :- (-72.9301,273.514)
# Uncertainity(x,y) :- (0.00211762,0.00187731)
#
# ---------------------------------
#
# Iteration :- 106
# Estimated position(x,y) :- (-77.7797,273.024)
# Uncertainity(x,y) :- (0.00211761,0.00187731)
#
# ---------------------------------
#
# Iteration :- 107
# Estimated position(x,y) :- (-82.3786,272.331)
# Uncertainity(x,y) :- (0.00211761,0.0018773)
#
# ---------------------------------
#
# Iteration :- 108
# Estimated position(x,y) :- (-87.5829,272.571)
# Uncertainity(x,y) :- (0.00211761,0.00187729)
#
# ---------------------------------
#
# Iteration :- 109
# Estimated position(x,y) :- (-92.3393,272.089)
# Uncertainity(x,y) :- (0.0021176,0.00187728)
#
# ---------------------------------
#
# Iteration :- 110
# Estimated position(x,y) :- (-97.3006,269.977)
# Uncertainity(x,y) :- (0.0021176,0.00187727)
#
# ---------------------------------
#
# Iteration :- 111
# Estimated position(x,y) :- (-102.096,270.029)
# Uncertainity(x,y) :- (0.0021176,0.00187726)
#
# ---------------------------------
#
# Iteration :- 112
# Estimated position(x,y) :- (-107.189,268.434)
# Uncertainity(x,y) :- (0.0021176,0.00187725)
#
# ---------------------------------
#
# Iteration :- 113
# Estimated position(x,y) :- (-112.133,267.066)
# Uncertainity(x,y) :- (0.0021176,0.00187724)
#
# ---------------------------------
#
# Iteration :- 114
# Estimated position(x,y) :- (-117.103,265.881)
# Uncertainity(x,y) :- (0.0021176,0.00187723)
#
# ---------------------------------
#
# Iteration :- 115
# Estimated position(x,y) :- (-121.904,264.337)
# Uncertainity(x,y) :- (0.0021176,0.00187722)
#
# ---------------------------------
#
# Iteration :- 116
# Estimated position(x,y) :- (-126.875,262.169)
# Uncertainity(x,y) :- (0.0021176,0.00187721)
#
# ---------------------------------
#
# Iteration :- 117
# Estimated position(x,y) :- (-132.021,261.03)
# Uncertainity(x,y) :- (0.0021176,0.0018772)
#
# ---------------------------------
#
# Iteration :- 118
# Estimated position(x,y) :- (-136.961,259.274)
# Uncertainity(x,y) :- (0.0021176,0.0018772)
#
# ---------------------------------
#
# Iteration :- 119
# Estimated position(x,y) :- (-142.043,257.615)
# Uncertainity(x,y) :- (0.0021176,0.00187719)
#
# ---------------------------------
#
# Iteration :- 120
# Estimated position(x,y) :- (-147.297,255.959)
# Uncertainity(x,y) :- (0.0021176,0.00187719)
#
# ---------------------------------
#
# Iteration :- 121
# Estimated position(x,y) :- (-152.314,254.348)
# Uncertainity(x,y) :- (0.0021176,0.00187718)
#
# ---------------------------------
#
# Iteration :- 122
# Estimated position(x,y) :- (-157.643,252.906)
# Uncertainity(x,y) :- (0.0021176,0.00187718)
#
# ---------------------------------
#
# Iteration :- 123
# Estimated position(x,y) :- (-162.305,251.327)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 124
# Estimated position(x,y) :- (-167.7,249.674)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 125
# Estimated position(x,y) :- (-172.707,247.248)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
# ---------------------------------
#
# Iteration :- 126
# Estimated position(x,y) :- (-177.592,245.807)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 127
# Estimated position(x,y) :- (-182.66,243.104)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 128
# Estimated position(x,y) :- (-187.275,241.7)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 129
# Estimated position(x,y) :- (-192.683,240.073)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 130
# Estimated position(x,y) :- (-197.328,238.152)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 131
# Estimated position(x,y) :- (-202.248,235.094)
# Uncertainity(x,y) :- (0.0021176,0.00187716)
#
# ---------------------------------
#
# Iteration :- 132
# Estimated position(x,y) :- (-207.627,233.161)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 133
# Estimated position(x,y) :- (-212.29,229.831)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 134
# Estimated position(x,y) :- (-217.388,227.393)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 135
# Estimated position(x,y) :- (-221.983,224.498)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 136
# Estimated position(x,y) :- (-228.21,221.02)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 137
# Estimated position(x,y) :- (-232.998,218.004)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 138
# Estimated position(x,y) :- (-237.866,215.07)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 139
# Estimated position(x,y) :- (-242.314,212.75)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 140
# Estimated position(x,y) :- (-247.663,209.293)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 141
# Estimated position(x,y) :- (-252.033,205.533)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 142
# Estimated position(x,y) :- (-257.278,201.589)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 143
# Estimated position(x,y) :- (-261.702,197.761)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 144
# Estimated position(x,y) :- (-266.771,194.171)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 145
# Estimated position(x,y) :- (-272.18,191.031)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 146
# Estimated position(x,y) :- (-276.006,187.471)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 147
# Estimated position(x,y) :- (-280.53,184.059)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 148
# Estimated position(x,y) :- (-285.601,179.413)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 149
# Estimated position(x,y) :- (-291.932,174.829)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 150
# Estimated position(x,y) :- (-296.454,170.617)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 151
# Estimated position(x,y) :- (-299.946,166.422)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 152
# Estimated position(x,y) :- (-303.33,162.206)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 153
# Estimated position(x,y) :- (-307.445,157.294)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 154
# Estimated position(x,y) :- (-312.541,152.805)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 155
# Estimated position(x,y) :- (-317.352,147.977)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 156
# Estimated position(x,y) :- (-321.296,143.216)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 157
# Estimated position(x,y) :- (-325.373,138.21)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 158
# Estimated position(x,y) :- (-328.197,132.934)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 159
# Estimated position(x,y) :- (-331.305,127.947)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 160
# Estimated position(x,y) :- (-334.225,122.778)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 161
# Estimated position(x,y) :- (-337.499,117.393)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 162
# Estimated position(x,y) :- (-341.551,111.8)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 163
# Estimated position(x,y) :- (-344.647,106.166)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 164
# Estimated position(x,y) :- (-347.9,100.252)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 165
# Estimated position(x,y) :- (-350.415,94.6788)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 166
# Estimated position(x,y) :- (-352.44,88.5155)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 167
# Estimated position(x,y) :- (-355.365,82.3774)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 168
# Estimated position(x,y) :- (-355.675,76.4648)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 169
# Estimated position(x,y) :- (-358.248,70.1531)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 170
# Estimated position(x,y) :- (-359.788,64.0715)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 171
# Estimated position(x,y) :- (-360.972,57.7135)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 172
# Estimated position(x,y) :- (-363.837,51.2284)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 173
# Estimated position(x,y) :- (-366.6,44.634)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 174
# Estimated position(x,y) :- (-367.516,38.2682)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 175
# Estimated position(x,y) :- (-368.383,31.8929)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 176
# Estimated position(x,y) :- (-370.398,25.4479)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 177
# Estimated position(x,y) :- (-370.465,18.8291)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 178
# Estimated position(x,y) :- (-370.768,12.2011)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 179
# Estimated position(x,y) :- (-370.187,5.56739)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 180
# Estimated position(x,y) :- (-370.772,-1.06614)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 181
# Estimated position(x,y) :- (-370.173,-7.69619)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 182
# Estimated position(x,y) :- (-369.946,-14.4072)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 183
# Estimated position(x,y) :- (-368.443,-21.0858)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 184
# Estimated position(x,y) :- (-367.22,-27.6966)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 185
# Estimated position(x,y) :- (-367.317,-34.2347)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 186
# Estimated position(x,y) :- (-368.114,-40.6861)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 187
# Estimated position(x,y) :- (-366.811,-47.0758)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 188
# Estimated position(x,y) :- (-365.982,-53.7111)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 189
# Estimated position(x,y) :- (-364.405,-60.2242)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 190
# Estimated position(x,y) :- (-363.096,-66.4846)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 191
# Estimated position(x,y) :- (-361.781,-73.0188)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 192
# Estimated position(x,y) :- (-359.002,-79.1556)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 193
# Estimated position(x,y) :- (-357.169,-85.1325)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 194
# Estimated position(x,y) :- (-355.444,-90.9895)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 195
# Estimated position(x,y) :- (-352.726,-97.0259)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 196
# Estimated position(x,y) :- (-350.273,-102.936)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 197
# Estimated position(x,y) :- (-346.587,-108.487)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 198
# Estimated position(x,y) :- (-343.108,-114.311)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 199
# Estimated position(x,y) :- (-340.293,-119.943)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 200
# Estimated position(x,y) :- (-335.932,-125.514)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 201
# Estimated position(x,y) :- (-331.491,-130.799)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 202
# Estimated position(x,y) :- (-327.294,-136.369)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 203
# Estimated position(x,y) :- (-324.445,-141.311)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 204
# Estimated position(x,y) :- (-319.962,-145.943)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 205
# Estimated position(x,y) :- (-316.085,-150.69)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 206
# Estimated position(x,y) :- (-311.642,-155.423)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 207
# Estimated position(x,y) :- (-306.51,-160.102)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 208
# Estimated position(x,y) :- (-301.557,-164.232)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 209
# Estimated position(x,y) :- (-298.028,-168.98)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 210
# Estimated position(x,y) :- (-293.17,-173.066)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 211
# Estimated position(x,y) :- (-287.922,-176.838)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 212
# Estimated position(x,y) :- (-283.392,-181.399)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 213
# Estimated position(x,y) :- (-278.131,-185.284)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 214
# Estimated position(x,y) :- (-274.584,-189.36)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 215
# Estimated position(x,y) :- (-270.105,-193.08)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 216
# Estimated position(x,y) :- (-264.972,-196.742)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 217
# Estimated position(x,y) :- (-260.909,-200.298)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 218
# Estimated position(x,y) :- (-255.903,-203.525)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 219
# Estimated position(x,y) :- (-251.264,-206.807)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 220
# Estimated position(x,y) :- (-246.359,-209.27)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 221
# Estimated position(x,y) :- (-240.933,-212.122)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 222
# Estimated position(x,y) :- (-235.716,-215.316)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 223
# Estimated position(x,y) :- (-230.711,-218.029)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 224
# Estimated position(x,y) :- (-225.22,-219.69)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 225
# Estimated position(x,y) :- (-219.719,-222.468)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 226
# Estimated position(x,y) :- (-215.1,-224.288)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 227
# Estimated position(x,y) :- (-209.984,-226.855)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 228
# Estimated position(x,y) :- (-204.793,-230.005)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 229
# Estimated position(x,y) :- (-199.469,-233.283)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 230
# Estimated position(x,y) :- (-195.311,-236.137)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 231
# Estimated position(x,y) :- (-191.067,-238.869)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 232
# Estimated position(x,y) :- (-186.042,-240.895)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 233
# Estimated position(x,y) :- (-180.844,-243.263)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 234
# Estimated position(x,y) :- (-176.128,-244.223)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 235
# Estimated position(x,y) :- (-170.714,-245.929)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 236
# Estimated position(x,y) :- (-165.603,-247.976)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 237
# Estimated position(x,y) :- (-161.243,-250.247)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 238
# Estimated position(x,y) :- (-156.617,-251.489)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 239
# Estimated position(x,y) :- (-151.253,-253.759)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 240
# Estimated position(x,y) :- (-146.447,-255.373)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 241
# Estimated position(x,y) :- (-142.001,-257.553)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 242
# Estimated position(x,y) :- (-137.329,-259.003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 243
# Estimated position(x,y) :- (-133.236,-260.003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 244
# Estimated position(x,y) :- (-128.034,-261.451)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 245
# Estimated position(x,y) :- (-123.426,-262.57)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 246
# Estimated position(x,y) :- (-118.723,-264.533)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 247
# Estimated position(x,y) :- (-113.859,-265.32)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 248
# Estimated position(x,y) :- (-109.191,-266.187)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 249
# Estimated position(x,y) :- (-104.195,-267.086)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 250
# Estimated position(x,y) :- (-99.2287,-268.24)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 251
# Estimated position(x,y) :- (-94.1622,-268.948)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 252
# Estimated position(x,y) :- (-89.6362,-269.565)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 253
# Estimated position(x,y) :- (-84.6495,-271.355)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 254
# Estimated position(x,y) :- (-79.6372,-271.935)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 255
# Estimated position(x,y) :- (-74.6183,-273.511)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 256
# Estimated position(x,y) :- (-69.797,-273.57)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 257
# Estimated position(x,y) :- (-64.8798,-274.141)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 258
# Estimated position(x,y) :- (-59.9643,-275.394)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 259
# Estimated position(x,y) :- (-54.9872,-276.877)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 260
# Estimated position(x,y) :- (-49.9575,-277.52)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
# ---------------------------------
#
# Iteration :- 261
# Estimated position(x,y) :- (-45.0609,-278.211)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 262
# Estimated position(x,y) :- (-40.0958,-278.388)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 263
# Estimated position(x,y) :- (-35.2598,-278.3)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 264
# Estimated position(x,y) :- (-30.376,-278.885)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 265
# Estimated position(x,y) :- (-25.457,-279.244)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 266
# Estimated position(x,y) :- (-20.5565,-280.305)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 267
# Estimated position(x,y) :- (-15.5967,-279.623)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 268
# Estimated position(x,y) :- (-10.7079,-279.517)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 269
# Estimated position(x,y) :- (-5.77818,-279.567)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 270
# Estimated position(x,y) :- (-0.860418,-278.706)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 271
# Estimated position(x,y) :- (4.04235,-278.78)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 272
# Estimated position(x,y) :- (8.93614,-278.978)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 273
# Estimated position(x,y) :- (13.8329,-279.774)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 274
# Estimated position(x,y) :- (18.7,-279.773)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 275
# Estimated position(x,y) :- (23.6452,-279.862)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 276
# Estimated position(x,y) :- (28.5832,-278.801)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 277
# Estimated position(x,y) :- (33.489,-278.118)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 278
# Estimated position(x,y) :- (38.3714,-277.718)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 279
# Estimated position(x,y) :- (43.2732,-276.109)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 280
# Estimated position(x,y) :- (48.1683,-276.332)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 281
# Estimated position(x,y) :- (52.964,-276.133)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 282
# Estimated position(x,y) :- (57.6992,-277.033)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 283
# Estimated position(x,y) :- (62.5399,-276.006)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 284
# Estimated position(x,y) :- (67.2741,-276.271)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 285
# Estimated position(x,y) :- (72.3349,-276.412)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 286
# Estimated position(x,y) :- (77.4829,-276.263)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 287
# Estimated position(x,y) :- (82.7376,-275.48)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 288
# Estimated position(x,y) :- (87.1866,-274.322)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 289
# Estimated position(x,y) :- (92.4628,-272.679)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 290
# Estimated position(x,y) :- (97.5477,-271.093)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 291
# Estimated position(x,y) :- (102.165,-269.341)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 292
# Estimated position(x,y) :- (107.305,-268.272)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 293
# Estimated position(x,y) :- (112.04,-267.355)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 294
# Estimated position(x,y) :- (117.364,-265.724)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 295
# Estimated position(x,y) :- (122.333,-263.748)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 296
# Estimated position(x,y) :- (127.473,-262.609)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 297
# Estimated position(x,y) :- (132.659,-261.365)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 298
# Estimated position(x,y) :- (137.73,-259.742)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 299
# Estimated position(x,y) :- (142.456,-258.153)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 300
# Estimated position(x,y) :- (147.244,-256.788)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 301
# Estimated position(x,y) :- (152.393,-253.95)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 302
# Estimated position(x,y) :- (157.16,-252.569)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 303
# Estimated position(x,y) :- (161.545,-250.589)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 304
# Estimated position(x,y) :- (166.439,-249.537)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 305
# Estimated position(x,y) :- (171.378,-247.452)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 306
# Estimated position(x,y) :- (176.458,-245.436)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 307
# Estimated position(x,y) :- (181.332,-243.616)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 308
# Estimated position(x,y) :- (186.904,-241.869)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 309
# Estimated position(x,y) :- (192.529,-240.135)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 310
# Estimated position(x,y) :- (197.238,-237.352)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 311
# Estimated position(x,y) :- (201.138,-234.423)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 312
# Estimated position(x,y) :- (206.675,-231.739)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 313
# Estimated position(x,y) :- (210.806,-229.683)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 314
# Estimated position(x,y) :- (215.777,-227.004)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 315
# Estimated position(x,y) :- (221.156,-223.427)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 316
# Estimated position(x,y) :- (226.598,-220.676)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 317
# Estimated position(x,y) :- (232.005,-217.451)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 318
# Estimated position(x,y) :- (236.951,-214.97)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 319
# Estimated position(x,y) :- (242.349,-211.641)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 320
# Estimated position(x,y) :- (247.19,-208.442)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 321
# Estimated position(x,y) :- (252.007,-205.266)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 322
# Estimated position(x,y) :- (256.314,-202.021)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 323
# Estimated position(x,y) :- (260.724,-199.248)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 324
# Estimated position(x,y) :- (265.761,-195.924)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 325
# Estimated position(x,y) :- (269.578,-192.188)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 326
# Estimated position(x,y) :- (274.771,-188.407)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 327
# Estimated position(x,y) :- (278.371,-184.508)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 328
# Estimated position(x,y) :- (283.02,-180.776)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 329
# Estimated position(x,y) :- (287.869,-176.462)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 330
# Estimated position(x,y) :- (293.053,-171.899)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 331
# Estimated position(x,y) :- (297.838,-167.825)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 332
# Estimated position(x,y) :- (301.728,-163.018)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 333
# Estimated position(x,y) :- (306.66,-157.87)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 334
# Estimated position(x,y) :- (310.486,-152.93)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 335
# Estimated position(x,y) :- (315.212,-148.407)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 336
# Estimated position(x,y) :- (320.3,-143.295)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 337
# Estimated position(x,y) :- (324.027,-138.537)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 338
# Estimated position(x,y) :- (327.354,-133.358)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 339
# Estimated position(x,y) :- (331.8,-128.476)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 340
# Estimated position(x,y) :- (334.938,-123.371)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 341
# Estimated position(x,y) :- (339.785,-117.813)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 342
# Estimated position(x,y) :- (342.962,-112.036)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 343
# Estimated position(x,y) :- (346.402,-106.134)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 344
# Estimated position(x,y) :- (350.113,-100.783)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 345
# Estimated position(x,y) :- (352.771,-95.0861)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 346
# Estimated position(x,y) :- (354.475,-89.4969)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 347
# Estimated position(x,y) :- (356.756,-83.5754)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 348
# Estimated position(x,y) :- (360.091,-77.5773)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 349
# Estimated position(x,y) :- (361.995,-71.3246)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 350
# Estimated position(x,y) :- (364.462,-65.0003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 351
# Estimated position(x,y) :- (366.131,-58.626)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 352
# Estimated position(x,y) :- (368.423,-52.1634)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 353
# Estimated position(x,y) :- (369.041,-45.6088)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 354
# Estimated position(x,y) :- (370.329,-39.1203)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 355
# Estimated position(x,y) :- (369.707,-32.6483)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 356
# Estimated position(x,y) :- (370.372,-25.96)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 357
# Estimated position(x,y) :- (370.952,-19.3881)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 358
# Estimated position(x,y) :- (369.972,-12.8119)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 359
# Estimated position(x,y) :- (371.052,-6.16309)
# Uncertainity(x,y) :- (0.00211759,0.00187716)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pred_state[p][0])
    br.append(est_state[p][0])
    m.append(pos[p][0])
# pred_state[2][0]
# plt.plot(i,ar,color='orange')
plt.plot(i,br,color='blue')
plt.plot(i,m,color='red')
plt.title("comparision of estimated x(blue) and measured x(red)")
plt.show()
# comparision of estimated x(blue) and measured x(red)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pred_state[p][3])
    br.append(est_state[p][3])
    m.append(pos[p][1])
# pred_state[2][0]
# plt.plot(i,ar,color='orange')
plt.plot(i,br,color='blue')
plt.plot(i,m,color='red')
plt.title("comparision of estimated y(blue) and measured y(red)")
plt.show()
# comparision of estimated y(blue) and measured y(red)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(est_state[p][0])
    br.append(est_state[p][3])
    m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='blue')
plt.title("estimated trajectory")
plt.show()
# plt.plot(i,br)
# plt.plot(i,m)
# estimated trajectory

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pos[p][0])
    br.append(pos[p][1])
#     m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='red')
plt.title("measured trajectory")
plt.show()
# plt.plot(i,br)
# plt.plot(i,m)
# measured trajectory

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
ar1=[]
br1=[]
ar2=[]
br2=[]
m=[]
for p in range(1,len(vel)):
    ar.append(est_state[p][0])
    br.append(est_state[p][3])    
    ar1.append(pred_state[p][0])
    br1.append(pred_state[p][3])
    ar2.append(pos[p][0])
    br2.append(pos[p][1])    
#     m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='blue')
# plt.plot(ar1,br1,color='orange')
plt.plot(ar2,br2,color='red')
plt.title("measured(red) and estimated(blue) trjectory")
# plt.plot(i,br)
# plt.plot(i,m)
# measured(red) and estimated(blue) trjectory
plt.show()
