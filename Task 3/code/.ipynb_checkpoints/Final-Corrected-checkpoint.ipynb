# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
# mpld3.enable_notebook()

# %%
file=open("kalmann.txt",'r')
pos=np.loadtxt("kalmann.txt",delimiter=',',usecols=[0,1])
vel=np.loadtxt("kalmann.txt",skiprows=1,delimiter=',',usecols=[2,3])
vel=np.insert(vel,[0],0,axis=0)

# %%
# defining varibles
del_t=0.075
sigma_ax=0.03
sigma_ay=0.02
sigma_x=0.1
sigma_y=0.1
sigma_vx=5
sigma_vy=5
pos_x0,pos_y0=pos[0]
p=1

# %%
pred_state=[]
est_state=[]
pred_p=[]
est_p=[]

# %%
F=np.zeros((6,6))
F[0,:3]=(1,del_t,0.5*del_t**2)
F[1,:3]=(0,1,del_t)
F[2,2]=1
F[3,3:6]=(1,del_t,0.5*del_t**2)
F[4,3:6]=(0,1,del_t)
F[5,5]=1
FT=np.transpose(F)
# F

# %%
# Q=np.zeros((6,6))
# Q[0,:3]=(0.05*del_t**5*sigma_ax**2,0.125*del_t**4*sigma_ax**2,(1/6)*del_t**3*sigma_ax**2)
# Q[1,:3]=(0,(1/3)*del_t**3*sigma_ax**2,0.5*del_t**2*sigma_ax**2)
# Q[2,:3]=(0,0,1*sigma_ax**2*del_t)
# Q[3,3:6]=(0.05*del_t**5*sigma_ay**2,0.125*del_t**4*sigma_ay**2,(1/6)*del_t**3*sigma_ay**2)
# Q[4,3:6]=(0,(1/3)*del_t**3*sigma_ay**2,0.5*del_t**2*sigma_ay**2)
# Q[5,3:6]=(0,0,1*sigma_ay**2*del_t)
# # Q=Q*sigma_ay**2
# # Q-Continuos noise

# %%
Q=np.zeros((6,6))
Q[0,:3]=(0.25*del_t**4*sigma_ax**2,0.5*del_t**3*sigma_ax**2,0.5*del_t**2*sigma_ax**2)
Q[1,:3]=(0,del_t**2*sigma_ax**2,del_t*sigma_ax**2)
Q[2,:3]=(0,0,1*sigma_ax**2)
Q[3,3:6]=(0.25*del_t**4*sigma_ay**2,0.5*del_t**3*sigma_ay**2,0.5*del_t**2*sigma_ay**2)
Q[4,3:6]=(0,del_t**2*sigma_ay**2,del_t*sigma_ay**2)
Q[5,3:6]=(0,0,1*sigma_ay**2)
# Q=Q*sigma_ay**2
# Q-Discrete noise

# %%
R=np.zeros((4,4))
R[0,0],R[1,1],R[2,2],R[3,3]=(sigma_x**2,sigma_vx**2,sigma_y**2,sigma_vy**2)
# R

# %%
H=np.zeros((4,6))
H[0,0],H[1,1],H[2,3],H[3,4] =(1,1,1,1)
HT=np.transpose(H)
# H

# %%
temp=np.zeros((6,1))
temp[:,0]=[pos_x0,0,0,pos_y0,0,0]
est_state.append(temp)
# est_state[0]

# %%
temp=np.diag((p,p,p,p,p,p))
est_p.append(temp)
# est_p[0]

# %%
def state_extrapolate(xn):
    xnext=np.dot(F,xn)
    return xnext

# %%
def cov_extrapolate(pn):
    pnext=np.dot(np.dot(F,pn),FT) +Q
    return pnext

# %%
def measure(n):
    z=np.zeros((4,1))
    z[:,0]=(pos[n,0],vel[n,0],pos[n,1],vel[n,1])
    return z

# %%
def K_gain(n):
    kn=np.dot(np.dot(pred_p[n-1],HT),(np.linalg.inv(np.dot(np.dot(H,pred_p[n-1]),HT)+R)))
    return kn

# %%
def state_update(xn_1,kn,zn):
    xn=xn_1 + np.dot(kn,(zn-np.dot(H,xn_1)))
    return xn

# %%
def cov_update(pn_1,kn):
    idm=(np.identity(6)-np.dot(kn,H))
    idmT=np.transpose(idm)
    pn=np.dot(np.dot(idm,pn_1),idmT)+ np.dot(np.dot(kn,R),np.transpose(kn))
    return pn

# %%
pred_state.append(state_extrapolate(est_state[0]))
pred_p.append(cov_extrapolate(est_p[0]))
for i in range(1,len(vel)):
    print("\n---------------------------------\n\nIteration :-",i)
    zi=measure(i)
    ki=K_gain(i)
    est_state.append(state_update(pred_state[i-1],ki,zi))
    print("Estimated position(x,y) :- (%g,%g)" % (est_state[i][0],est_state[i][3]))
    est_p.append(cov_update(pred_p[i-1],ki))
    pred_state.append(state_extrapolate(est_state[i]))
    print("Uncertainity(x,y) :- (%g,%g)" % (est_p[i][0,0],est_p[i][3,3]))
    pred_p.append(cov_extrapolate(est_p[i]))
# Out:
# ---------------------------------
#
# Iteration :- 1
# Estimated position(x,y) :- (368.252,6.51046)
# Uncertainity(x,y) :- (0.00986913,0.00986913)
#
# ---------------------------------
#
# Iteration :- 2
# Estimated position(x,y) :- (368.973,10.1377)
# Uncertainity(x,y) :- (0.0058299,0.0058299)
#
# ---------------------------------
#
# Iteration :- 3
# Estimated position(x,y) :- (373.539,15.9763)
# Uncertainity(x,y) :- (0.00554743,0.0055474)
#
# ---------------------------------
#
# Iteration :- 4
# Estimated position(x,y) :- (370.079,22.6209)
# Uncertainity(x,y) :- (0.00549573,0.00549568)
#
# ---------------------------------
#
# Iteration :- 5
# Estimated position(x,y) :- (370.042,29.6226)
# Uncertainity(x,y) :- (0.00523554,0.00523542)
#
# ---------------------------------
#
# Iteration :- 6
# Estimated position(x,y) :- (370.234,36.945)
# Uncertainity(x,y) :- (0.00489637,0.00489613)
#
# ---------------------------------
#
# Iteration :- 7
# Estimated position(x,y) :- (369.264,43.8849)
# Uncertainity(x,y) :- (0.00458327,0.00458282)
#
# ---------------------------------
#
# Iteration :- 8
# Estimated position(x,y) :- (366.856,50.5227)
# Uncertainity(x,y) :- (0.00433986,0.00433908)
#
# ---------------------------------
#
# Iteration :- 9
# Estimated position(x,y) :- (363.29,57.0023)
# Uncertainity(x,y) :- (0.00417514,0.00417392)
#
# ---------------------------------
#
# Iteration :- 10
# Estimated position(x,y) :- (357.613,63.8124)
# Uncertainity(x,y) :- (0.00407905,0.0040773)
#
# ---------------------------------
#
# Iteration :- 11
# Estimated position(x,y) :- (355.402,70.5732)
# Uncertainity(x,y) :- (0.00403091,0.00402863)
#
# ---------------------------------
#
# Iteration :- 12
# Estimated position(x,y) :- (353.742,77.1158)
# Uncertainity(x,y) :- (0.00400673,0.00400399)
#
# ---------------------------------
#
# Iteration :- 13
# Estimated position(x,y) :- (350.974,82.5949)
# Uncertainity(x,y) :- (0.00398583,0.00398272)
#
# ---------------------------------
#
# Iteration :- 14
# Estimated position(x,y) :- (349.989,89.0164)
# Uncertainity(x,y) :- (0.00395467,0.00395126)
#
# ---------------------------------
#
# Iteration :- 15
# Estimated position(x,y) :- (345.831,95.0502)
# Uncertainity(x,y) :- (0.00390724,0.00390359)
#
# ---------------------------------
#
# Iteration :- 16
# Estimated position(x,y) :- (343.25,100.197)
# Uncertainity(x,y) :- (0.00384316,0.00383925)
#
# ---------------------------------
#
# Iteration :- 17
# Estimated position(x,y) :- (340.63,106.02)
# Uncertainity(x,y) :- (0.00376513,0.00376091)
#
# ---------------------------------
#
# Iteration :- 18
# Estimated position(x,y) :- (336.996,111.32)
# Uncertainity(x,y) :- (0.00367698,0.00367236)
#
# ---------------------------------
#
# Iteration :- 19
# Estimated position(x,y) :- (334.016,116.78)
# Uncertainity(x,y) :- (0.00358253,0.00357735)
#
# ---------------------------------
#
# Iteration :- 20
# Estimated position(x,y) :- (331.181,121.349)
# Uncertainity(x,y) :- (0.00348496,0.00347907)
#
# ---------------------------------
#
# Iteration :- 21
# Estimated position(x,y) :- (329.188,126.824)
# Uncertainity(x,y) :- (0.0033868,0.00337998)
#
# ---------------------------------
#
# Iteration :- 22
# Estimated position(x,y) :- (326.896,131.213)
# Uncertainity(x,y) :- (0.00328987,0.0032819)
#
# ---------------------------------
#
# Iteration :- 23
# Estimated position(x,y) :- (324.18,136.581)
# Uncertainity(x,y) :- (0.00319546,0.00318607)
#
# ---------------------------------
#
# Iteration :- 24
# Estimated position(x,y) :- (319.934,141.485)
# Uncertainity(x,y) :- (0.00310444,0.00309333)
#
# ---------------------------------
#
# Iteration :- 25
# Estimated position(x,y) :- (316.581,146.741)
# Uncertainity(x,y) :- (0.00301737,0.0030042)
#
# ---------------------------------
#
# Iteration :- 26
# Estimated position(x,y) :- (311.333,151.35)
# Uncertainity(x,y) :- (0.00293459,0.00291898)
#
# ---------------------------------
#
# Iteration :- 27
# Estimated position(x,y) :- (306.606,156.439)
# Uncertainity(x,y) :- (0.0028563,0.00283783)
#
# ---------------------------------
#
# Iteration :- 28
# Estimated position(x,y) :- (302.021,161.141)
# Uncertainity(x,y) :- (0.00278256,0.00276079)
#
# ---------------------------------
#
# Iteration :- 29
# Estimated position(x,y) :- (297.484,165.536)
# Uncertainity(x,y) :- (0.00271341,0.00268783)
#
# ---------------------------------
#
# Iteration :- 30
# Estimated position(x,y) :- (292.512,169.808)
# Uncertainity(x,y) :- (0.00264881,0.00261889)
#
# ---------------------------------
#
# Iteration :- 31
# Estimated position(x,y) :- (287.855,175.619)
# Uncertainity(x,y) :- (0.00258871,0.00255388)
#
# ---------------------------------
#
# Iteration :- 32
# Estimated position(x,y) :- (282.25,180.591)
# Uncertainity(x,y) :- (0.00253303,0.00249269)
#
# ---------------------------------
#
# Iteration :- 33
# Estimated position(x,y) :- (279.16,183.822)
# Uncertainity(x,y) :- (0.00248168,0.00243522)
#
# ---------------------------------
#
# Iteration :- 34
# Estimated position(x,y) :- (274.464,187.837)
# Uncertainity(x,y) :- (0.00243455,0.00238134)
#
# ---------------------------------
#
# Iteration :- 35
# Estimated position(x,y) :- (269.804,191.157)
# Uncertainity(x,y) :- (0.00239155,0.00233095)
#
# ---------------------------------
#
# Iteration :- 36
# Estimated position(x,y) :- (266.55,195.185)
# Uncertainity(x,y) :- (0.00235256,0.00228394)
#
# ---------------------------------
#
# Iteration :- 37
# Estimated position(x,y) :- (262.57,199.393)
# Uncertainity(x,y) :- (0.00231743,0.00224021)
#
# ---------------------------------
#
# Iteration :- 38
# Estimated position(x,y) :- (257.99,202.586)
# Uncertainity(x,y) :- (0.00228604,0.00219965)
#
# ---------------------------------
#
# Iteration :- 39
# Estimated position(x,y) :- (252.526,206.509)
# Uncertainity(x,y) :- (0.00225822,0.00216218)
#
# ---------------------------------
#
# Iteration :- 40
# Estimated position(x,y) :- (247.49,209.382)
# Uncertainity(x,y) :- (0.0022338,0.0021277)
#
# ---------------------------------
#
# Iteration :- 41
# Estimated position(x,y) :- (242.237,212.863)
# Uncertainity(x,y) :- (0.00221259,0.00209611)
#
# ---------------------------------
#
# Iteration :- 42
# Estimated position(x,y) :- (237.553,216.747)
# Uncertainity(x,y) :- (0.00219439,0.00206731)
#
# ---------------------------------
#
# Iteration :- 43
# Estimated position(x,y) :- (232.621,219.145)
# Uncertainity(x,y) :- (0.00217898,0.00204119)
#
# ---------------------------------
#
# Iteration :- 44
# Estimated position(x,y) :- (227.551,222.386)
# Uncertainity(x,y) :- (0.00216611,0.00201767)
#
# ---------------------------------
#
# Iteration :- 45
# Estimated position(x,y) :- (222.274,225.248)
# Uncertainity(x,y) :- (0.00215554,0.00199661)
#
# ---------------------------------
#
# Iteration :- 46
# Estimated position(x,y) :- (217.047,228.513)
# Uncertainity(x,y) :- (0.00214702,0.00197792)
#
# ---------------------------------
#
# Iteration :- 47
# Estimated position(x,y) :- (211.574,231.422)
# Uncertainity(x,y) :- (0.0021403,0.00196144)
#
# ---------------------------------
#
# Iteration :- 48
# Estimated position(x,y) :- (205.869,234.014)
# Uncertainity(x,y) :- (0.00213512,0.00194707)
#
# ---------------------------------
#
# Iteration :- 49
# Estimated position(x,y) :- (200.634,236.066)
# Uncertainity(x,y) :- (0.00213125,0.00193464)
#
# ---------------------------------
#
# Iteration :- 50
# Estimated position(x,y) :- (195.329,238.601)
# Uncertainity(x,y) :- (0.00212844,0.00192402)
#
# ---------------------------------
#
# Iteration :- 51
# Estimated position(x,y) :- (190.173,240.143)
# Uncertainity(x,y) :- (0.0021265,0.00191506)
#
# ---------------------------------
#
# Iteration :- 52
# Estimated position(x,y) :- (184.925,242.448)
# Uncertainity(x,y) :- (0.00212523,0.0019076)
#
# ---------------------------------
#
# Iteration :- 53
# Estimated position(x,y) :- (180.108,244.239)
# Uncertainity(x,y) :- (0.00212446,0.00190147)
#
# ---------------------------------
#
# Iteration :- 54
# Estimated position(x,y) :- (174.827,246.075)
# Uncertainity(x,y) :- (0.00212403,0.00189654)
#
# ---------------------------------
#
# Iteration :- 55
# Estimated position(x,y) :- (169.819,247.28)
# Uncertainity(x,y) :- (0.00212384,0.00189264)
#
# ---------------------------------
#
# Iteration :- 56
# Estimated position(x,y) :- (164.904,249.08)
# Uncertainity(x,y) :- (0.00212378,0.00188963)
#
# ---------------------------------
#
# Iteration :- 57
# Estimated position(x,y) :- (160.34,251.735)
# Uncertainity(x,y) :- (0.00212378,0.00188736)
#
# ---------------------------------
#
# Iteration :- 58
# Estimated position(x,y) :- (155.852,252.427)
# Uncertainity(x,y) :- (0.00212378,0.00188571)
#
# ---------------------------------
#
# Iteration :- 59
# Estimated position(x,y) :- (150.795,254.853)
# Uncertainity(x,y) :- (0.00212374,0.00188455)
#
# ---------------------------------
#
# Iteration :- 60
# Estimated position(x,y) :- (145.748,255.73)
# Uncertainity(x,y) :- (0.00212363,0.00188379)
#
# ---------------------------------
#
# Iteration :- 61
# Estimated position(x,y) :- (140.458,257.276)
# Uncertainity(x,y) :- (0.00212346,0.00188331)
#
# ---------------------------------
#
# Iteration :- 62
# Estimated position(x,y) :- (136.297,258.543)
# Uncertainity(x,y) :- (0.00212322,0.00188305)
#
# ---------------------------------
#
# Iteration :- 63
# Estimated position(x,y) :- (131.477,260.914)
# Uncertainity(x,y) :- (0.00212291,0.00188292)
#
# ---------------------------------
#
# Iteration :- 64
# Estimated position(x,y) :- (126.299,261.583)
# Uncertainity(x,y) :- (0.00212254,0.00188288)
#
# ---------------------------------
#
# Iteration :- 65
# Estimated position(x,y) :- (121.278,262.443)
# Uncertainity(x,y) :- (0.00212214,0.00188288)
#
# ---------------------------------
#
# Iteration :- 66
# Estimated position(x,y) :- (116.382,263.778)
# Uncertainity(x,y) :- (0.0021217,0.00188288)
#
# ---------------------------------
#
# Iteration :- 67
# Estimated position(x,y) :- (111.892,264.738)
# Uncertainity(x,y) :- (0.00212125,0.00188286)
#
# ---------------------------------
#
# Iteration :- 68
# Estimated position(x,y) :- (106.855,264.647)
# Uncertainity(x,y) :- (0.00212081,0.0018828)
#
# ---------------------------------
#
# Iteration :- 69
# Estimated position(x,y) :- (102.179,265.831)
# Uncertainity(x,y) :- (0.00212037,0.00188269)
#
# ---------------------------------
#
# Iteration :- 70
# Estimated position(x,y) :- (97.323,267.316)
# Uncertainity(x,y) :- (0.00211996,0.00188253)
#
# ---------------------------------
#
# Iteration :- 71
# Estimated position(x,y) :- (92.5535,268.15)
# Uncertainity(x,y) :- (0.00211959,0.00188233)
#
# ---------------------------------
#
# Iteration :- 72
# Estimated position(x,y) :- (87.7599,268.73)
# Uncertainity(x,y) :- (0.00211924,0.00188207)
#
# ---------------------------------
#
# Iteration :- 73
# Estimated position(x,y) :- (83.0252,269.391)
# Uncertainity(x,y) :- (0.00211894,0.00188178)
#
# ---------------------------------
#
# Iteration :- 74
# Estimated position(x,y) :- (78.1994,269.981)
# Uncertainity(x,y) :- (0.00211868,0.00188145)
#
# ---------------------------------
#
# Iteration :- 75
# Estimated position(x,y) :- (73.1928,271.911)
# Uncertainity(x,y) :- (0.00211846,0.00188111)
#
# ---------------------------------
#
# Iteration :- 76
# Estimated position(x,y) :- (68.6807,271.59)
# Uncertainity(x,y) :- (0.00211828,0.00188075)
#
# ---------------------------------
#
# Iteration :- 77
# Estimated position(x,y) :- (63.9494,272.202)
# Uncertainity(x,y) :- (0.00211813,0.00188039)
#
# ---------------------------------
#
# Iteration :- 78
# Estimated position(x,y) :- (58.9992,273.435)
# Uncertainity(x,y) :- (0.00211802,0.00188003)
#
# ---------------------------------
#
# Iteration :- 79
# Estimated position(x,y) :- (54.1636,274.481)
# Uncertainity(x,y) :- (0.00211793,0.00187968)
#
# ---------------------------------
#
# Iteration :- 80
# Estimated position(x,y) :- (49.4224,275.304)
# Uncertainity(x,y) :- (0.00211787,0.00187936)
#
# ---------------------------------
#
# Iteration :- 81
# Estimated position(x,y) :- (44.6045,275.095)
# Uncertainity(x,y) :- (0.00211782,0.00187905)
#
# ---------------------------------
#
# Iteration :- 82
# Estimated position(x,y) :- (39.6669,275.521)
# Uncertainity(x,y) :- (0.00211779,0.00187877)
#
# ---------------------------------
#
# Iteration :- 83
# Estimated position(x,y) :- (34.7938,275.08)
# Uncertainity(x,y) :- (0.00211778,0.00187851)
#
# ---------------------------------
#
# Iteration :- 84
# Estimated position(x,y) :- (30.0779,276.513)
# Uncertainity(x,y) :- (0.00211777,0.00187829)
#
# ---------------------------------
#
# Iteration :- 85
# Estimated position(x,y) :- (25.1442,278.436)
# Uncertainity(x,y) :- (0.00211776,0.00187809)
#
# ---------------------------------
#
# Iteration :- 86
# Estimated position(x,y) :- (20.2832,278.205)
# Uncertainity(x,y) :- (0.00211776,0.00187792)
#
# ---------------------------------
#
# Iteration :- 87
# Estimated position(x,y) :- (15.3347,277.6)
# Uncertainity(x,y) :- (0.00211776,0.00187778)
#
# ---------------------------------
#
# Iteration :- 88
# Estimated position(x,y) :- (10.4348,277.995)
# Uncertainity(x,y) :- (0.00211777,0.00187766)
#
# ---------------------------------
#
# Iteration :- 89
# Estimated position(x,y) :- (5.52225,278.541)
# Uncertainity(x,y) :- (0.00211776,0.00187757)
#
# ---------------------------------
#
# Iteration :- 90
# Estimated position(x,y) :- (0.52669,278.845)
# Uncertainity(x,y) :- (0.00211776,0.00187749)
#
# ---------------------------------
#
# Iteration :- 91
# Estimated position(x,y) :- (-4.38551,279.772)
# Uncertainity(x,y) :- (0.00211776,0.00187744)
#
# ---------------------------------
#
# Iteration :- 92
# Estimated position(x,y) :- (-9.26348,279.698)
# Uncertainity(x,y) :- (0.00211775,0.00187739)
#
# ---------------------------------
#
# Iteration :- 93
# Estimated position(x,y) :- (-14.1441,279.881)
# Uncertainity(x,y) :- (0.00211774,0.00187736)
#
# ---------------------------------
#
# Iteration :- 94
# Estimated position(x,y) :- (-19.087,280.424)
# Uncertainity(x,y) :- (0.00211773,0.00187734)
#
# ---------------------------------
#
# Iteration :- 95
# Estimated position(x,y) :- (-23.9355,279.707)
# Uncertainity(x,y) :- (0.00211772,0.00187733)
#
# ---------------------------------
#
# Iteration :- 96
# Estimated position(x,y) :- (-28.8197,278.651)
# Uncertainity(x,y) :- (0.00211771,0.00187733)
#
# ---------------------------------
#
# Iteration :- 97
# Estimated position(x,y) :- (-33.6821,278.301)
# Uncertainity(x,y) :- (0.0021177,0.00187732)
#
# ---------------------------------
#
# Iteration :- 98
# Estimated position(x,y) :- (-38.5513,278.248)
# Uncertainity(x,y) :- (0.00211769,0.00187732)
#
# ---------------------------------
#
# Iteration :- 99
# Estimated position(x,y) :- (-43.5074,277.269)
# Uncertainity(x,y) :- (0.00211767,0.00187732)
#
# ---------------------------------
#
# Iteration :- 100
# Estimated position(x,y) :- (-48.2663,276.634)
# Uncertainity(x,y) :- (0.00211766,0.00187732)
#
# ---------------------------------
#
# Iteration :- 101
# Estimated position(x,y) :- (-53.4714,275.585)
# Uncertainity(x,y) :- (0.00211765,0.00187732)
#
# ---------------------------------
#
# Iteration :- 102
# Estimated position(x,y) :- (-58.3554,274.457)
# Uncertainity(x,y) :- (0.00211764,0.00187732)
#
# ---------------------------------
#
# Iteration :- 103
# Estimated position(x,y) :- (-63.0213,274.106)
# Uncertainity(x,y) :- (0.00211763,0.00187732)
#
# ---------------------------------
#
# Iteration :- 104
# Estimated position(x,y) :- (-67.833,273.619)
# Uncertainity(x,y) :- (0.00211763,0.00187731)
#
# ---------------------------------
#
# Iteration :- 105
# Estimated position(x,y) :- (-72.9302,273.518)
# Uncertainity(x,y) :- (0.00211762,0.00187731)
#
# ---------------------------------
#
# Iteration :- 106
# Estimated position(x,y) :- (-77.7799,273.028)
# Uncertainity(x,y) :- (0.00211761,0.0018773)
#
# ---------------------------------
#
# Iteration :- 107
# Estimated position(x,y) :- (-82.3788,272.335)
# Uncertainity(x,y) :- (0.00211761,0.0018773)
#
# ---------------------------------
#
# Iteration :- 108
# Estimated position(x,y) :- (-87.5831,272.575)
# Uncertainity(x,y) :- (0.00211761,0.00187729)
#
# ---------------------------------
#
# Iteration :- 109
# Estimated position(x,y) :- (-92.3395,272.093)
# Uncertainity(x,y) :- (0.0021176,0.00187728)
#
# ---------------------------------
#
# Iteration :- 110
# Estimated position(x,y) :- (-97.3008,269.981)
# Uncertainity(x,y) :- (0.0021176,0.00187727)
#
# ---------------------------------
#
# Iteration :- 111
# Estimated position(x,y) :- (-102.096,270.033)
# Uncertainity(x,y) :- (0.0021176,0.00187726)
#
# ---------------------------------
#
# Iteration :- 112
# Estimated position(x,y) :- (-107.189,268.438)
# Uncertainity(x,y) :- (0.0021176,0.00187725)
#
# ---------------------------------
#
# Iteration :- 113
# Estimated position(x,y) :- (-112.133,267.069)
# Uncertainity(x,y) :- (0.0021176,0.00187724)
#
# ---------------------------------
#
# Iteration :- 114
# Estimated position(x,y) :- (-117.104,265.885)
# Uncertainity(x,y) :- (0.0021176,0.00187723)
#
# ---------------------------------
#
# Iteration :- 115
# Estimated position(x,y) :- (-121.904,264.34)
# Uncertainity(x,y) :- (0.0021176,0.00187722)
#
# ---------------------------------
#
# Iteration :- 116
# Estimated position(x,y) :- (-126.875,262.171)
# Uncertainity(x,y) :- (0.0021176,0.00187721)
#
# ---------------------------------
#
# Iteration :- 117
# Estimated position(x,y) :- (-132.021,261.032)
# Uncertainity(x,y) :- (0.0021176,0.0018772)
#
# ---------------------------------
#
# Iteration :- 118
# Estimated position(x,y) :- (-136.961,259.276)
# Uncertainity(x,y) :- (0.0021176,0.0018772)
#
# ---------------------------------
#
# Iteration :- 119
# Estimated position(x,y) :- (-142.043,257.617)
# Uncertainity(x,y) :- (0.0021176,0.00187719)
#
# ---------------------------------
#
# Iteration :- 120
# Estimated position(x,y) :- (-147.297,255.961)
# Uncertainity(x,y) :- (0.0021176,0.00187718)
#
# ---------------------------------
#
# Iteration :- 121
# Estimated position(x,y) :- (-152.314,254.35)
# Uncertainity(x,y) :- (0.0021176,0.00187718)
#
# ---------------------------------
#
# Iteration :- 122
# Estimated position(x,y) :- (-157.643,252.908)
# Uncertainity(x,y) :- (0.0021176,0.00187718)
#
# ---------------------------------
#
# Iteration :- 123
# Estimated position(x,y) :- (-162.305,251.328)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 124
# Estimated position(x,y) :- (-167.7,249.675)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 125
# Estimated position(x,y) :- (-172.707,247.249)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 126
# Estimated position(x,y) :- (-177.592,245.808)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 127
# Estimated position(x,y) :- (-182.66,243.104)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 128
# Estimated position(x,y) :- (-187.275,241.7)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 129
# Estimated position(x,y) :- (-192.683,240.073)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 130
# Estimated position(x,y) :- (-197.328,238.152)
# Uncertainity(x,y) :- (0.0021176,0.00187717)
#
# ---------------------------------
#
# Iteration :- 131
# Estimated position(x,y) :- (-202.248,235.094)
# Uncertainity(x,y) :- (0.0021176,0.00187716)
#
# ---------------------------------
#
# Iteration :- 132
# Estimated position(x,y) :- (-207.627,233.161)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 133
# Estimated position(x,y) :- (-212.29,229.831)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 134
# Estimated position(x,y) :- (-217.388,227.392)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 135
# Estimated position(x,y) :- (-221.983,224.497)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 136
# Estimated position(x,y) :- (-228.21,221.02)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 137
# Estimated position(x,y) :- (-232.998,218.003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 138
# Estimated position(x,y) :- (-237.866,215.069)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 139
# Estimated position(x,y) :- (-242.314,212.749)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 140
# Estimated position(x,y) :- (-247.663,209.292)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 141
# Estimated position(x,y) :- (-252.033,205.533)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 142
# Estimated position(x,y) :- (-257.278,201.589)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 143
# Estimated position(x,y) :- (-261.702,197.761)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 144
# Estimated position(x,y) :- (-266.771,194.17)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 145
# Estimated position(x,y) :- (-272.18,191.03)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 146
# Estimated position(x,y) :- (-276.006,187.47)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 147
# Estimated position(x,y) :- (-280.53,184.058)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 148
# Estimated position(x,y) :- (-285.601,179.412)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 149
# Estimated position(x,y) :- (-291.932,174.828)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 150
# Estimated position(x,y) :- (-296.454,170.617)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 151
# Estimated position(x,y) :- (-299.946,166.421)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 152
# Estimated position(x,y) :- (-303.33,162.206)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 153
# Estimated position(x,y) :- (-307.445,157.294)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 154
# Estimated position(x,y) :- (-312.541,152.805)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 155
# Estimated position(x,y) :- (-317.352,147.977)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 156
# Estimated position(x,y) :- (-321.296,143.215)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 157
# Estimated position(x,y) :- (-325.373,138.21)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 158
# Estimated position(x,y) :- (-328.197,132.933)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 159
# Estimated position(x,y) :- (-331.305,127.947)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 160
# Estimated position(x,y) :- (-334.225,122.777)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 161
# Estimated position(x,y) :- (-337.499,117.393)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 162
# Estimated position(x,y) :- (-341.551,111.8)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 163
# Estimated position(x,y) :- (-344.647,106.166)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 164
# Estimated position(x,y) :- (-347.9,100.252)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 165
# Estimated position(x,y) :- (-350.415,94.6788)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 166
# Estimated position(x,y) :- (-352.44,88.5155)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 167
# Estimated position(x,y) :- (-355.365,82.3774)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 168
# Estimated position(x,y) :- (-355.675,76.4649)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 169
# Estimated position(x,y) :- (-358.248,70.1531)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 170
# Estimated position(x,y) :- (-359.788,64.0715)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 171
# Estimated position(x,y) :- (-360.972,57.7135)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 172
# Estimated position(x,y) :- (-363.837,51.2285)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 173
# Estimated position(x,y) :- (-366.6,44.6341)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 174
# Estimated position(x,y) :- (-367.516,38.2683)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 175
# Estimated position(x,y) :- (-368.383,31.893)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 176
# Estimated position(x,y) :- (-370.398,25.448)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 177
# Estimated position(x,y) :- (-370.465,18.8292)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 178
# Estimated position(x,y) :- (-370.768,12.2012)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 179
# Estimated position(x,y) :- (-370.187,5.56749)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 180
# Estimated position(x,y) :- (-370.772,-1.06604)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 181
# Estimated position(x,y) :- (-370.173,-7.6961)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 182
# Estimated position(x,y) :- (-369.946,-14.4071)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 183
# Estimated position(x,y) :- (-368.443,-21.0857)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 184
# Estimated position(x,y) :- (-367.22,-27.6965)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 185
# Estimated position(x,y) :- (-367.317,-34.2347)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 186
# Estimated position(x,y) :- (-368.114,-40.6861)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 187
# Estimated position(x,y) :- (-366.811,-47.0758)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 188
# Estimated position(x,y) :- (-365.982,-53.711)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 189
# Estimated position(x,y) :- (-364.405,-60.2241)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 190
# Estimated position(x,y) :- (-363.096,-66.4845)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 191
# Estimated position(x,y) :- (-361.781,-73.0187)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 192
# Estimated position(x,y) :- (-359.002,-79.1556)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 193
# Estimated position(x,y) :- (-357.169,-85.1325)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 194
# Estimated position(x,y) :- (-355.444,-90.9895)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 195
# Estimated position(x,y) :- (-352.726,-97.0259)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 196
# Estimated position(x,y) :- (-350.273,-102.936)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 197
# Estimated position(x,y) :- (-346.587,-108.487)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 198
# Estimated position(x,y) :- (-343.108,-114.311)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 199
# Estimated position(x,y) :- (-340.293,-119.943)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 200
# Estimated position(x,y) :- (-335.932,-125.514)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 201
# Estimated position(x,y) :- (-331.491,-130.799)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 202
# Estimated position(x,y) :- (-327.294,-136.369)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 203
# Estimated position(x,y) :- (-324.445,-141.311)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 204
# Estimated position(x,y) :- (-319.962,-145.943)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 205
# Estimated position(x,y) :- (-316.085,-150.69)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 206
# Estimated position(x,y) :- (-311.642,-155.423)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 207
# Estimated position(x,y) :- (-306.51,-160.102)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 208
# Estimated position(x,y) :- (-301.557,-164.232)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 209
# Estimated position(x,y) :- (-298.028,-168.98)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 210
# Estimated position(x,y) :- (-293.17,-173.066)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 211
# Estimated position(x,y) :- (-287.922,-176.838)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 212
# Estimated position(x,y) :- (-283.392,-181.399)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 213
# Estimated position(x,y) :- (-278.131,-185.284)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 214
# Estimated position(x,y) :- (-274.584,-189.36)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 215
# Estimated position(x,y) :- (-270.105,-193.08)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 216
# Estimated position(x,y) :- (-264.972,-196.742)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 217
# Estimated position(x,y) :- (-260.909,-200.298)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 218
# Estimated position(x,y) :- (-255.903,-203.525)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 219
# Estimated position(x,y) :- (-251.264,-206.807)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 220
# Estimated position(x,y) :- (-246.359,-209.27)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 221
# Estimated position(x,y) :- (-240.933,-212.122)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 222
# Estimated position(x,y) :- (-235.716,-215.316)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 223
# Estimated position(x,y) :- (-230.711,-218.029)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 224
# Estimated position(x,y) :- (-225.22,-219.69)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 225
# Estimated position(x,y) :- (-219.719,-222.468)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 226
# Estimated position(x,y) :- (-215.1,-224.288)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 227
# Estimated position(x,y) :- (-209.984,-226.855)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 228
# Estimated position(x,y) :- (-204.793,-230.005)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 229
# Estimated position(x,y) :- (-199.469,-233.283)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 230
# Estimated position(x,y) :- (-195.311,-236.137)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 231
# Estimated position(x,y) :- (-191.067,-238.869)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 232
# Estimated position(x,y) :- (-186.042,-240.895)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 233
# Estimated position(x,y) :- (-180.844,-243.263)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 234
# Estimated position(x,y) :- (-176.128,-244.223)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 235
# Estimated position(x,y) :- (-170.714,-245.929)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 236
# Estimated position(x,y) :- (-165.603,-247.976)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 237
# Estimated position(x,y) :- (-161.243,-250.247)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 238
# Estimated position(x,y) :- (-156.617,-251.489)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 239
# Estimated position(x,y) :- (-151.253,-253.759)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 240
# Estimated position(x,y) :- (-146.447,-255.373)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 241
# Estimated position(x,y) :- (-142.001,-257.553)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 242
# Estimated position(x,y) :- (-137.329,-259.003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 243
# Estimated position(x,y) :- (-133.236,-260.003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 244
# Estimated position(x,y) :- (-128.034,-261.451)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 245
# Estimated position(x,y) :- (-123.426,-262.57)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 246
# Estimated position(x,y) :- (-118.723,-264.533)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 247
# Estimated position(x,y) :- (-113.859,-265.32)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 248
# Estimated position(x,y) :- (-109.191,-266.187)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 249
# Estimated position(x,y) :- (-104.195,-267.086)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 250
# Estimated position(x,y) :- (-99.2287,-268.24)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 251
# Estimated position(x,y) :- (-94.1622,-268.948)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 252
# Estimated position(x,y) :- (-89.6362,-269.565)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 253
# Estimated position(x,y) :- (-84.6495,-271.355)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 254
# Estimated position(x,y) :- (-79.6372,-271.935)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 255
# Estimated position(x,y) :- (-74.6183,-273.511)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 256
# Estimated position(x,y) :- (-69.797,-273.57)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 257
# Estimated position(x,y) :- (-64.8798,-274.141)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 258
# Estimated position(x,y) :- (-59.9643,-275.394)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 259
# Estimated position(x,y) :- (-54.9872,-276.877)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 260
# Estimated position(x,y) :- (-49.9575,-277.52)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 261
# Estimated position(x,y) :- (-45.0609,-278.211)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 262
# Estimated position(x,y) :- (-40.0958,-278.388)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 263
# Estimated position(x,y) :- (-35.2598,-278.3)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 264
# Estimated position(x,y) :- (-30.376,-278.885)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 265
# Estimated position(x,y) :- (-25.457,-279.244)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 266
# Estimated position(x,y) :- (-20.5565,-280.305)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 267
# Estimated position(x,y) :- (-15.5967,-279.623)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 268
# Estimated position(x,y) :- (-10.7079,-279.517)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 269
# Estimated position(x,y) :- (-5.77818,-279.567)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 270
# Estimated position(x,y) :- (-0.860418,-278.706)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 271
# Estimated position(x,y) :- (4.04235,-278.78)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 272
# Estimated position(x,y) :- (8.93614,-278.978)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 273
# Estimated position(x,y) :- (13.8329,-279.774)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 274
# Estimated position(x,y) :- (18.7,-279.773)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 275
# Estimated position(x,y) :- (23.6452,-279.862)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 276
# Estimated position(x,y) :- (28.5832,-278.801)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 277
# Estimated position(x,y) :- (33.489,-278.118)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 278
# Estimated position(x,y) :- (38.3714,-277.718)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 279
# Estimated position(x,y) :- (43.2732,-276.109)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 280
# Estimated position(x,y) :- (48.1683,-276.332)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 281
# Estimated position(x,y) :- (52.964,-276.133)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 282
# Estimated position(x,y) :- (57.6992,-277.033)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 283
# Estimated position(x,y) :- (62.5399,-276.006)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 284
# Estimated position(x,y) :- (67.2741,-276.271)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 285
# Estimated position(x,y) :- (72.3349,-276.412)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 286
# Estimated position(x,y) :- (77.4829,-276.263)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 287
# Estimated position(x,y) :- (82.7376,-275.48)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 288
# Estimated position(x,y) :- (87.1866,-274.322)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 289
# Estimated position(x,y) :- (92.4628,-272.679)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 290
# Estimated position(x,y) :- (97.5477,-271.093)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 291
# Estimated position(x,y) :- (102.165,-269.341)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 292
# Estimated position(x,y) :- (107.305,-268.272)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 293
# Estimated position(x,y) :- (112.04,-267.355)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 294
# Estimated position(x,y) :- (117.364,-265.724)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 295
# Estimated position(x,y) :- (122.333,-263.748)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 296
# Estimated position(x,y) :- (127.473,-262.609)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 297
# Estimated position(x,y) :- (132.659,-261.365)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 298
# Estimated position(x,y) :- (137.73,-259.742)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 299
# Estimated position(x,y) :- (142.456,-258.153)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 300
# Estimated position(x,y) :- (147.244,-256.788)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 301
# Estimated position(x,y) :- (152.393,-253.95)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 302
# Estimated position(x,y) :- (157.16,-252.569)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 303
# Estimated position(x,y) :- (161.545,-250.589)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 304
# Estimated position(x,y) :- (166.439,-249.537)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 305
# Estimated position(x,y) :- (171.378,-247.452)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 306
# Estimated position(x,y) :- (176.458,-245.436)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 307
# Estimated position(x,y) :- (181.332,-243.616)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 308
# Estimated position(x,y) :- (186.904,-241.869)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 309
# Estimated position(x,y) :- (192.529,-240.135)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 310
# Estimated position(x,y) :- (197.238,-237.352)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 311
# Estimated position(x,y) :- (201.138,-234.423)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 312
# Estimated position(x,y) :- (206.675,-231.739)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 313
# Estimated position(x,y) :- (210.806,-229.683)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 314
# Estimated position(x,y) :- (215.777,-227.004)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 315
# Estimated position(x,y) :- (221.156,-223.427)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 316
# Estimated position(x,y) :- (226.598,-220.676)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 317
# Estimated position(x,y) :- (232.005,-217.451)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 318
# Estimated position(x,y) :- (236.951,-214.97)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 319
# Estimated position(x,y) :- (242.349,-211.641)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 320
# Estimated position(x,y) :- (247.19,-208.442)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 321
# Estimated position(x,y) :- (252.007,-205.266)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 322
# Estimated position(x,y) :- (256.314,-202.021)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 323
# Estimated position(x,y) :- (260.724,-199.248)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 324
# Estimated position(x,y) :- (265.761,-195.924)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 325
# Estimated position(x,y) :- (269.578,-192.188)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 326
# Estimated position(x,y) :- (274.771,-188.407)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 327
# Estimated position(x,y) :- (278.371,-184.508)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 328
# Estimated position(x,y) :- (283.02,-180.776)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 329
# Estimated position(x,y) :- (287.869,-176.462)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 330
# Estimated position(x,y) :- (293.053,-171.899)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 331
# Estimated position(x,y) :- (297.838,-167.825)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 332
# Estimated position(x,y) :- (301.728,-163.018)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 333
# Estimated position(x,y) :- (306.66,-157.87)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 334
# Estimated position(x,y) :- (310.486,-152.93)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 335
# Estimated position(x,y) :- (315.212,-148.407)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 336
# Estimated position(x,y) :- (320.3,-143.295)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 337
# Estimated position(x,y) :- (324.027,-138.537)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 338
# Estimated position(x,y) :- (327.354,-133.358)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 339
# Estimated position(x,y) :- (331.8,-128.476)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 340
# Estimated position(x,y) :- (334.938,-123.371)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 341
# Estimated position(x,y) :- (339.785,-117.813)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 342
# Estimated position(x,y) :- (342.962,-112.036)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 343
# Estimated position(x,y) :- (346.402,-106.134)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 344
# Estimated position(x,y) :- (350.113,-100.783)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 345
# Estimated position(x,y) :- (352.771,-95.0861)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 346
# Estimated position(x,y) :- (354.475,-89.4969)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 347
# Estimated position(x,y) :- (356.756,-83.5754)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 348
# Estimated position(x,y) :- (360.091,-77.5773)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 349
# Estimated position(x,y) :- (361.995,-71.3246)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 350
# Estimated position(x,y) :- (364.462,-65.0003)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 351
# Estimated position(x,y) :- (366.131,-58.626)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 352
# Estimated position(x,y) :- (368.423,-52.1634)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 353
# Estimated position(x,y) :- (369.041,-45.6088)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 354
# Estimated position(x,y) :- (370.329,-39.1203)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 355
# Estimated position(x,y) :- (369.707,-32.6483)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 356
# Estimated position(x,y) :- (370.372,-25.96)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 357
# Estimated position(x,y) :- (370.952,-19.3881)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 358
# Estimated position(x,y) :- (369.972,-12.8119)
# Uncertainity(x,y) :- (0.00211759,0.00187716)
#
# ---------------------------------
#
# Iteration :- 359
# Estimated position(x,y) :- (371.052,-6.16309)
# Uncertainity(x,y) :- (0.00211759,0.00187716)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pred_state[p][0])
    br.append(est_state[p][0])
    m.append(pos[p][0])
# pred_state[2][0]
# plt.plot(i,ar,color='orange')
plt.plot(i,br,color='blue')
plt.plot(i,m,color='red')
plt.title("comparision of estimated x(blue) and measured x(red)")
plt.show()
# comparision of estimated x(blue) and measured x(red)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pred_state[p][3])
    br.append(est_state[p][3])
    m.append(pos[p][1])
# pred_state[2][0]
# plt.plot(i,ar,color='orange')
plt.plot(i,br,color='blue')
plt.plot(i,m,color='red')
plt.title("comparision of estimated y(blue) and measured y(red)")
plt.show()
# comparision of estimated y(blue) and measured y(red)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(est_state[p][0])
    br.append(est_state[p][3])
    m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='blue')
plt.title("estimated trajectory")
plt.show()
# plt.plot(i,br)
# plt.plot(i,m)
# estimated trajectory

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pos[p][0])
    br.append(pos[p][1])
#     m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='red')
plt.title("measured trajectory")
plt.show()
# plt.plot(i,br)
# plt.plot(i,m)
# measured trajectory

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
ar1=[]
br1=[]
ar2=[]
br2=[]
m=[]
for p in range(1,len(vel)):
    ar.append(est_state[p][0])
    br.append(est_state[p][3])    
    ar1.append(pred_state[p][0])
    br1.append(pred_state[p][3])
    ar2.append(pos[p][0])
    br2.append(pos[p][1])    
#     m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='blue')
# plt.plot(ar1,br1,color='orange')
plt.plot(ar2,br2,color='red')
plt.title("measured(red) and estimated(blue) trjectory")
# plt.plot(i,br)
# plt.plot(i,m)
# measured(red) and estimated(blue) trjectory
plt.show()
