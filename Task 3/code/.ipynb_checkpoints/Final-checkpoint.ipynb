# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import mpld3
# mpld3.enable_notebook()

# %%
file=open("kalmann.txt",'r')
pos=np.loadtxt("kalmann.txt",delimiter=',',usecols=[0,1])
vel=np.loadtxt("kalmann.txt",skiprows=1,delimiter=',',usecols=[2,3])
vel=np.insert(vel,[0],0,axis=0)

# %%
# defining varibles
del_t=0.075
sigma_ax=15
sigma_ay=15
sigma_x=0.6
sigma_y=0.3
sigma_vx=5
sigma_vy=5
pos_x0,pos_y0=pos[0]
p=0.15

# %%
pred_state=[]
est_state=[]
pred_p=[]
est_p=[]

# %%
F=np.zeros((6,6))
F[0,:3]=(1,del_t,0.5*del_t**2)
F[1,:3]=(0,1,del_t)
F[2,2]=1
F[3,3:6]=(1,del_t,0.5*del_t**2)
F[4,3:6]=(0,1,del_t)
F[5,5]=1
FT=np.transpose(F)
# F

# %%
# Q=np.zeros((6,6))
# Q[0,:3]=(0.05*del_t**5*sigma_ax**2,0.125*del_t**4*sigma_ax**2,(1/6)*del_t**3*sigma_ax**2)
# Q[1,:3]=(0,(1/3)*del_t**3*sigma_ax**2,0.5*del_t**2*sigma_ax**2)
# Q[2,:3]=(0,0,1*sigma_ax**2*del_t)
# Q[3,3:6]=(0.05*del_t**5*sigma_ay**2,0.125*del_t**4*sigma_ay**2,(1/6)*del_t**3*sigma_ay**2)
# Q[4,3:6]=(0,(1/3)*del_t**3*sigma_ay**2,0.5*del_t**2*sigma_ay**2)
# Q[5,3:6]=(0,0,1*sigma_ay**2*del_t)
# # Q=Q*sigma_ay**2
# # Q-Continuos noise

# %%
Q=np.zeros((6,6))
Q[0,:3]=(0.25*del_t**4*sigma_ax**2,0.5*del_t**3*sigma_ax**2,0.5*del_t**2*sigma_ax**2)
Q[1,:3]=(0,del_t**2*sigma_ax**2,del_t*sigma_ax**2)
Q[2,:3]=(0,0,1*sigma_ax**2)
Q[3,3:6]=(0.25*del_t**4*sigma_ay**2,0.5*del_t**3*sigma_ay**2,0.5*del_t**2*sigma_ay**2)
Q[4,3:6]=(0,del_t**2*sigma_ay**2,del_t*sigma_ay**2)
Q[5,3:6]=(0,0,1*sigma_ay**2)
# Q=Q*sigma_ay**2
# Q-Discrete noise

# %%
R=np.zeros((4,4))
R[0,0],R[1,1],R[2,2],R[3,3]=(sigma_x**2,sigma_vx**2,sigma_y**2,sigma_vy**2)
# R

# %%
H=np.zeros((4,6))
H[0,0],H[1,1],H[2,3],H[3,4] =(1,1,1,1)
HT=np.transpose(H)
# H

# %%
temp=np.zeros((6,1))
temp[:,0]=[pos_x0,0,0,pos_y0,0,0]
est_state.append(temp)
# est_state[0]

# %%
temp=np.diag((p,p,p,p,p,p))
est_p.append(temp)
# est_p[0]

# %%
def state_extrapolate(xn):
    xnext=np.dot(F,xn)
    return xnext

# %%
def cov_extrapolate(pn):
    pnext=np.dot(np.dot(F,pn),FT) +Q
    return pnext

# %%
def measure(n):
    z=np.zeros((4,1))
    z[:,0]=(pos[n,0],vel[n,0],pos[n,1],vel[n,1])
    return z

# %%
def K_gain(n):
    kn=np.dot(np.dot(pred_p[n-1],HT),(np.linalg.inv(np.dot(np.dot(H,pred_p[n-1]),HT)+R)))
    return kn

# %%
def state_update(xn_1,kn,zn):
    xn=xn_1 + np.dot(kn,(zn-np.dot(H,xn_1)))
    return xn

# %%
def cov_update(pn_1,kn):
    idm=(np.identity(6)-np.dot(kn,H))
    idmT=np.transpose(idm)
    pn=np.dot(np.dot(idm,pn_1),idmT)+ np.dot(np.dot(kn,R),np.transpose(kn))
    return pn

# %%
pred_state.append(state_extrapolate(est_state[0]))
pred_p.append(cov_extrapolate(est_p[0]))
for i in range(1,len(vel)):
    print("\n---------------------------------\n\nIteration :-",i)
    zi=measure(i)
    ki=K_gain(1)
    est_state.append(state_update(est_state[i-1],ki,zi))
    print("Estimated position(x,y) :- (%g,%g)" % (est_state[i][0],est_state[i][3]))
    est_p.append(cov_update(est_p[i-1],ki))
    pred_state.append(state_extrapolate(est_state[i]))
    print("Uncertainity(x,y) :- (%g,%g)" % (est_p[i][0,0],est_p[i][3,3]))
    pred_p.append(cov_extrapolate(est_p[i]))
# Out:
# ---------------------------------
#
# Iteration :- 1
# Estimated position(x,y) :- (371.566,4.15464)
# Uncertainity(x,y) :- (0.10595,0.056271)
#
# ---------------------------------
#
# Iteration :- 2
# Estimated position(x,y) :- (370.953,9.52703)
# Uncertainity(x,y) :- (0.0842196,0.0433707)
#
# ---------------------------------
#
# Iteration :- 3
# Estimated position(x,y) :- (372.77,15.9888)
# Uncertainity(x,y) :- (0.0734975,0.0415942)
#
# ---------------------------------
#
# Iteration :- 4
# Estimated position(x,y) :- (370.66,22.0724)
# Uncertainity(x,y) :- (0.068206,0.0413492)
#
# ---------------------------------
#
# Iteration :- 5
# Estimated position(x,y) :- (370.479,28.371)
# Uncertainity(x,y) :- (0.0655938,0.0413154)
#
# ---------------------------------
#
# Iteration :- 6
# Estimated position(x,y) :- (370.484,35.1576)
# Uncertainity(x,y) :- (0.0643039,0.0413107)
#
# ---------------------------------
#
# Iteration :- 7
# Estimated position(x,y) :- (369.779,41.4456)
# Uncertainity(x,y) :- (0.0636667,0.0413101)
#
# ---------------------------------
#
# Iteration :- 8
# Estimated position(x,y) :- (368.079,47.4879)
# Uncertainity(x,y) :- (0.0633519,0.04131)
#
# ---------------------------------
#
# Iteration :- 9
# Estimated position(x,y) :- (365.524,53.5187)
# Uncertainity(x,y) :- (0.0631964,0.04131)
#
# ---------------------------------
#
# Iteration :- 10
# Estimated position(x,y) :- (361.412,60.2475)
# Uncertainity(x,y) :- (0.0631196,0.0413101)
#
# ---------------------------------
#
# Iteration :- 11
# Estimated position(x,y) :- (359.88,66.8065)
# Uncertainity(x,y) :- (0.0630817,0.0413101)
#
# ---------------------------------
#
# Iteration :- 12
# Estimated position(x,y) :- (358.588,73.0479)
# Uncertainity(x,y) :- (0.0630631,0.0413102)
#
# ---------------------------------
#
# Iteration :- 13
# Estimated position(x,y) :- (356.312,77.7764)
# Uncertainity(x,y) :- (0.0630541,0.0413102)
#
# ---------------------------------
#
# Iteration :- 14
# Estimated position(x,y) :- (355.312,84.7188)
# Uncertainity(x,y) :- (0.0630498,0.0413102)
#
# ---------------------------------
#
# Iteration :- 15
# Estimated position(x,y) :- (351.765,90.6951)
# Uncertainity(x,y) :- (0.0630478,0.0413102)
#
# ---------------------------------
#
# Iteration :- 16
# Estimated position(x,y) :- (349.48,95.3315)
# Uncertainity(x,y) :- (0.063047,0.0413103)
#
# ---------------------------------
#
# Iteration :- 17
# Estimated position(x,y) :- (347.1,101.674)
# Uncertainity(x,y) :- (0.0630467,0.0413103)
#
# ---------------------------------
#
# Iteration :- 18
# Estimated position(x,y) :- (343.851,106.871)
# Uncertainity(x,y) :- (0.0630468,0.0413103)
#
# ---------------------------------
#
# Iteration :- 19
# Estimated position(x,y) :- (341.149,112.585)
# Uncertainity(x,y) :- (0.0630469,0.0413103)
#
# ---------------------------------
#
# Iteration :- 20
# Estimated position(x,y) :- (338.528,116.647)
# Uncertainity(x,y) :- (0.0630471,0.0413103)
#
# ---------------------------------
#
# Iteration :- 21
# Estimated position(x,y) :- (336.603,122.993)
# Uncertainity(x,y) :- (0.0630473,0.0413103)
#
# ---------------------------------
#
# Iteration :- 22
# Estimated position(x,y) :- (334.329,126.782)
# Uncertainity(x,y) :- (0.0630475,0.0413104)
#
# ---------------------------------
#
# Iteration :- 23
# Estimated position(x,y) :- (331.628,133.157)
# Uncertainity(x,y) :- (0.0630477,0.0413104)
#
# ---------------------------------
#
# Iteration :- 24
# Estimated position(x,y) :- (327.469,138.016)
# Uncertainity(x,y) :- (0.0630478,0.0413104)
#
# ---------------------------------
#
# Iteration :- 25
# Estimated position(x,y) :- (324.316,143.784)
# Uncertainity(x,y) :- (0.063048,0.0413104)
#
# ---------------------------------
#
# Iteration :- 26
# Estimated position(x,y) :- (319.239,147.898)
# Uncertainity(x,y) :- (0.0630481,0.0413104)
#
# ---------------------------------
#
# Iteration :- 27
# Estimated position(x,y) :- (314.881,153.572)
# Uncertainity(x,y) :- (0.0630483,0.0413104)
#
# ---------------------------------
#
# Iteration :- 28
# Estimated position(x,y) :- (310.726,158.072)
# Uncertainity(x,y) :- (0.0630484,0.0413104)
#
# ---------------------------------
#
# Iteration :- 29
# Estimated position(x,y) :- (306.632,162.125)
# Uncertainity(x,y) :- (0.0630485,0.0413104)
#
# ---------------------------------
#
# Iteration :- 30
# Estimated position(x,y) :- (302.038,166.291)
# Uncertainity(x,y) :- (0.0630486,0.0413104)
#
# ---------------------------------
#
# Iteration :- 31
# Estimated position(x,y) :- (297.847,174.518)
# Uncertainity(x,y) :- (0.0630487,0.0413104)
#
# ---------------------------------
#
# Iteration :- 32
# Estimated position(x,y) :- (292.512,178.993)
# Uncertainity(x,y) :- (0.0630487,0.0413104)
#
# ---------------------------------
#
# Iteration :- 33
# Estimated position(x,y) :- (290.309,179.342)
# Uncertainity(x,y) :- (0.0630488,0.0413104)
#
# ---------------------------------
#
# Iteration :- 34
# Estimated position(x,y) :- (285.804,183.975)
# Uncertainity(x,y) :- (0.0630489,0.0413104)
#
# ---------------------------------
#
# Iteration :- 35
# Estimated position(x,y) :- (281.377,186.564)
# Uncertainity(x,y) :- (0.0630489,0.0413104)
#
# ---------------------------------
#
# Iteration :- 36
# Estimated position(x,y) :- (278.737,191.912)
# Uncertainity(x,y) :- (0.063049,0.0413104)
#
# ---------------------------------
#
# Iteration :- 37
# Estimated position(x,y) :- (274.901,197.118)
# Uncertainity(x,y) :- (0.063049,0.0413104)
#
# ---------------------------------
#
# Iteration :- 38
# Estimated position(x,y) :- (270.234,198.921)
# Uncertainity(x,y) :- (0.063049,0.0413104)
#
# ---------------------------------
#
# Iteration :- 39
# Estimated position(x,y) :- (264.486,204.059)
# Uncertainity(x,y) :- (0.0630491,0.0413104)
#
# ---------------------------------
#
# Iteration :- 40
# Estimated position(x,y) :- (259.542,205.486)
# Uncertainity(x,y) :- (0.0630491,0.0413104)
#
# ---------------------------------
#
# Iteration :- 41
# Estimated position(x,y) :- (254.367,210.027)
# Uncertainity(x,y) :- (0.0630491,0.0413104)
#
# ---------------------------------
#
# Iteration :- 42
# Estimated position(x,y) :- (250.044,215.344)
# Uncertainity(x,y) :- (0.0630492,0.0413104)
#
# ---------------------------------
#
# Iteration :- 43
# Estimated position(x,y) :- (245.298,215.29)
# Uncertainity(x,y) :- (0.0630492,0.0413104)
#
# ---------------------------------
#
# Iteration :- 44
# Estimated position(x,y) :- (240.356,219.852)
# Uncertainity(x,y) :- (0.0630492,0.0413104)
#
# ---------------------------------
#
# Iteration :- 45
# Estimated position(x,y) :- (235.145,222.602)
# Uncertainity(x,y) :- (0.0630492,0.0413104)
#
# ---------------------------------
#
# Iteration :- 46
# Estimated position(x,y) :- (230.057,226.997)
# Uncertainity(x,y) :- (0.0630492,0.0413104)
#
# ---------------------------------
#
# Iteration :- 47
# Estimated position(x,y) :- (224.644,229.706)
# Uncertainity(x,y) :- (0.0630493,0.0413104)
#
# ---------------------------------
#
# Iteration :- 48
# Estimated position(x,y) :- (218.969,231.758)
# Uncertainity(x,y) :- (0.0630493,0.0413104)
#
# ---------------------------------
#
# Iteration :- 49
# Estimated position(x,y) :- (214.041,232.693)
# Uncertainity(x,y) :- (0.0630493,0.0413104)
#
# ---------------------------------
#
# Iteration :- 50
# Estimated position(x,y) :- (208.951,236.327)
# Uncertainity(x,y) :- (0.0630493,0.0413104)
#
# ---------------------------------
#
# Iteration :- 51
# Estimated position(x,y) :- (204.037,236.267)
# Uncertainity(x,y) :- (0.0630493,0.0413104)
#
# ---------------------------------
#
# Iteration :- 52
# Estimated position(x,y) :- (198.923,240.232)
# Uncertainity(x,y) :- (0.0630493,0.0413104)
#
# ---------------------------------
#
# Iteration :- 53
# Estimated position(x,y) :- (194.382,241.711)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 54
# Estimated position(x,y) :- (189.055,243.907)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 55
# Estimated position(x,y) :- (184.134,244.11)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 56
# Estimated position(x,y) :- (179.282,247.4)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 57
# Estimated position(x,y) :- (174.857,252.87)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 58
# Estimated position(x,y) :- (170.403,250.02)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 59
# Estimated position(x,y) :- (165.038,255.725)
# Uncertainity(x,y) :- (0.0630493,0.0413105)
#
# ---------------------------------
#
# Iteration :- 60
# Estimated position(x,y) :- (159.758,254.201)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 61
# Estimated position(x,y) :- (154.184,256.855)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 62
# Estimated position(x,y) :- (150.287,258.08)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 63
# Estimated position(x,y) :- (145.242,263.28)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 64
# Estimated position(x,y) :- (139.713,260.927)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 65
# Estimated position(x,y) :- (134.511,261.507)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 66
# Estimated position(x,y) :- (129.518,264.15)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 67
# Estimated position(x,y) :- (125.085,264.855)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 68
# Estimated position(x,y) :- (119.78,262.435)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 69
# Estimated position(x,y) :- (115.049,266.239)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 70
# Estimated position(x,y) :- (110.024,269.489)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 71
# Estimated position(x,y) :- (105.139,269.444)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 72
# Estimated position(x,y) :- (100.213,269.268)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 73
# Estimated position(x,y) :- (95.3752,270.051)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 74
# Estimated position(x,y) :- (90.3996,270.686)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 75
# Estimated position(x,y) :- (85.1892,275.941)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 76
# Estimated position(x,y) :- (80.7356,271.336)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 77
# Estimated position(x,y) :- (75.8917,272.956)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 78
# Estimated position(x,y) :- (70.7429,276.126)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 79
# Estimated position(x,y) :- (65.8155,277.363)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 80
# Estimated position(x,y) :- (61.0343,277.699)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 81
# Estimated position(x,y) :- (56.1326,274.898)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 82
# Estimated position(x,y) :- (51.0755,276.159)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 83
# Estimated position(x,y) :- (46.1499,274.085)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 84
# Estimated position(x,y) :- (41.458,279.644)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 85
# Estimated position(x,y) :- (36.4294,284.01)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 86
# Estimated position(x,y) :- (31.5395,279.256)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 87
# Estimated position(x,y) :- (26.5337,276.349)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 88
# Estimated position(x,y) :- (21.6238,278.582)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 89
# Estimated position(x,y) :- (16.7035,280.199)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 90
# Estimated position(x,y) :- (11.6738,280.307)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 91
# Estimated position(x,y) :- (6.79033,282.666)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 92
# Estimated position(x,y) :- (1.95075,280.622)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 93
# Estimated position(x,y) :- (-2.90315,280.82)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 94
# Estimated position(x,y) :- (-7.85094,282.27)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 95
# Estimated position(x,y) :- (-12.6551,278.866)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 96
# Estimated position(x,y) :- (-17.5258,276.319)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 97
# Estimated position(x,y) :- (-22.3677,277.448)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 98
# Estimated position(x,y) :- (-27.2261,278.791)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 99
# Estimated position(x,y) :- (-32.2094,276.195)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 100
# Estimated position(x,y) :- (-36.8954,276.073)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 101
# Estimated position(x,y) :- (-42.2453,274.42)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 102
# Estimated position(x,y) :- (-47.055,273.163)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 103
# Estimated position(x,y) :- (-51.5794,274.873)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 104
# Estimated position(x,y) :- (-56.3802,274.866)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 105
# Estimated position(x,y) :- (-61.5933,275.918)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 106
# Estimated position(x,y) :- (-66.3933,274.88)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 107
# Estimated position(x,y) :- (-70.8591,273.558)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 108
# Estimated position(x,y) :- (-76.2534,275.858)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 109
# Estimated position(x,y) :- (-80.9149,274.264)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 110
# Estimated position(x,y) :- (-85.9091,267.937)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 111
# Estimated position(x,y) :- (-90.6487,272.004)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 112
# Estimated position(x,y) :- (-95.834,267.865)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 113
# Estimated position(x,y) :- (-100.753,266.397)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 114
# Estimated position(x,y) :- (-105.708,265.833)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 115
# Estimated position(x,y) :- (-110.419,263.825)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 116
# Estimated position(x,y) :- (-115.408,260.26)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 117
# Estimated position(x,y) :- (-120.628,261.423)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 118
# Estimated position(x,y) :- (-125.503,259.147)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 119
# Estimated position(x,y) :- (-130.593,257.763)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 120
# Estimated position(x,y) :- (-135.9,256.407)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 121
# Estimated position(x,y) :- (-140.815,255.19)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 122
# Estimated position(x,y) :- (-146.19,254.433)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 123
# Estimated position(x,y) :- (-150.564,252.863)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 124
# Estimated position(x,y) :- (-156.098,251.149)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 125
# Estimated position(x,y) :- (-160.987,246.997)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 126
# Estimated position(x,y) :- (-165.739,247.553)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 127
# Estimated position(x,y) :- (-170.805,242.639)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 128
# Estimated position(x,y) :- (-175.225,243.837)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 129
# Estimated position(x,y) :- (-180.87,242.619)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 130
# Estimated position(x,y) :- (-185.316,240.183)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 131
# Estimated position(x,y) :- (-190.256,234.365)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 132
# Estimated position(x,y) :- (-195.845,234.466)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 133
# Estimated position(x,y) :- (-200.313,228.667)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 134
# Estimated position(x,y) :- (-205.499,227.862)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 135
# Estimated position(x,y) :- (-209.937,224.661)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 136
# Estimated position(x,y) :- (-216.771,219.978)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 137
# Estimated position(x,y) :- (-221.233,218.017)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 138
# Estimated position(x,y) :- (-225.942,215.925)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 139
# Estimated position(x,y) :- (-230.132,215.57)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 140
# Estimated position(x,y) :- (-235.743,210.179)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 141
# Estimated position(x,y) :- (-239.854,205.321)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 142
# Estimated position(x,y) :- (-245.359,200.921)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 143
# Estimated position(x,y) :- (-249.598,197.608)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 144
# Estimated position(x,y) :- (-254.876,195.11)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 145
# Estimated position(x,y) :- (-260.555,193.678)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 146
# Estimated position(x,y) :- (-263.868,189.857)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 147
# Estimated position(x,y) :- (-268.474,186.894)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 148
# Estimated position(x,y) :- (-273.875,179.647)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 149
# Estimated position(x,y) :- (-280.926,174.712)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 150
# Estimated position(x,y) :- (-285.026,171.662)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 151
# Estimated position(x,y) :- (-287.867,168.207)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 152
# Estimated position(x,y) :- (-290.946,164.464)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 153
# Estimated position(x,y) :- (-295.341,158.312)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 154
# Estimated position(x,y) :- (-301.118,154.759)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 155
# Estimated position(x,y) :- (-306.24,149.725)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 156
# Estimated position(x,y) :- (-310.038,145.358)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 157
# Estimated position(x,y) :- (-314.169,140.192)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 158
# Estimated position(x,y) :- (-316.602,134.531)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 159
# Estimated position(x,y) :- (-319.79,130.442)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 160
# Estimated position(x,y) :- (-322.874,125.418)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 161
# Estimated position(x,y) :- (-326.602,119.85)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 162
# Estimated position(x,y) :- (-331.421,114.005)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 163
# Estimated position(x,y) :- (-334.684,108.513)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 164
# Estimated position(x,y) :- (-338.259,102.307)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 165
# Estimated position(x,y) :- (-340.805,97.792)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 166
# Estimated position(x,y) :- (-342.85,90.8662)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 167
# Estimated position(x,y) :- (-346.397,84.8803)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 168
# Estimated position(x,y) :- (-346.188,79.8887)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 169
# Estimated position(x,y) :- (-349.756,73.2177)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 170
# Estimated position(x,y) :- (-351.683,67.8688)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 171
# Estimated position(x,y) :- (-353.225,61.3602)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 172
# Estimated position(x,y) :- (-357.283,54.8005)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 173
# Estimated position(x,y) :- (-360.851,48.2092)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 174
# Estimated position(x,y) :- (-361.601,42.671)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 175
# Estimated position(x,y) :- (-362.588,36.7737)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 176
# Estimated position(x,y) :- (-365.393,30.5146)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 177
# Estimated position(x,y) :- (-365.288,23.7251)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 178
# Estimated position(x,y) :- (-365.881,17.2084)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 179
# Estimated position(x,y) :- (-365.401,10.7777)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 180
# Estimated position(x,y) :- (-366.881,4.3738)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 181
# Estimated position(x,y) :- (-366.591,-2.03014)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 182
# Estimated position(x,y) :- (-367.037,-8.73552)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 183
# Estimated position(x,y) :- (-365.713,-15.2189)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 184
# Estimated position(x,y) :- (-365.102,-21.5084)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 185
# Estimated position(x,y) :- (-366.465,-27.7027)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 186
# Estimated position(x,y) :- (-368.532,-33.8042)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 187
# Estimated position(x,y) :- (-367.251,-39.9366)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 188
# Estimated position(x,y) :- (-366.889,-47.0987)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 189
# Estimated position(x,y) :- (-365.503,-53.5013)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 190
# Estimated position(x,y) :- (-364.686,-59.1529)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 191
# Estimated position(x,y) :- (-363.9,-66.2113)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 192
# Estimated position(x,y) :- (-361.062,-71.6381)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 193
# Estimated position(x,y) :- (-359.914,-77.1247)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 194
# Estimated position(x,y) :- (-358.893,-82.7125)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 195
# Estimated position(x,y) :- (-356.413,-89.2943)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 196
# Estimated position(x,y) :- (-354.493,-95.2756)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 197
# Estimated position(x,y) :- (-350.877,-100.205)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 198
# Estimated position(x,y) :- (-347.869,-106.734)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 199
# Estimated position(x,y) :- (-345.931,-112.374)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 200
# Estimated position(x,y) :- (-341.719,-118.055)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 201
# Estimated position(x,y) :- (-337.695,-122.963)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 202
# Estimated position(x,y) :- (-334.211,-129.384)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 203
# Estimated position(x,y) :- (-332.669,-133.389)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 204
# Estimated position(x,y) :- (-328.488,-137.333)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 205
# Estimated position(x,y) :- (-325.32,-142.551)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 206
# Estimated position(x,y) :- (-321.288,-147.824)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 207
# Estimated position(x,y) :- (-316.362,-152.95)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 208
# Estimated position(x,y) :- (-311.891,-156.32)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 209
# Estimated position(x,y) :- (-309.492,-162.739)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 210
# Estimated position(x,y) :- (-304.886,-166.174)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 211
# Estimated position(x,y) :- (-299.818,-169.423)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 212
# Estimated position(x,y) :- (-295.9,-176.16)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 213
# Estimated position(x,y) :- (-290.846,-179.511)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 214
# Estimated position(x,y) :- (-288.297,-184.261)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 215
# Estimated position(x,y) :- (-284.046,-187.734)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 216
# Estimated position(x,y) :- (-278.834,-191.573)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 217
# Estimated position(x,y) :- (-275.253,-195.343)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 218
# Estimated position(x,y) :- (-270.146,-198.271)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 219
# Estimated position(x,y) :- (-265.651,-202.022)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 220
# Estimated position(x,y) :- (-260.742,-203.139)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 221
# Estimated position(x,y) :- (-255.133,-207.008)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 222
# Estimated position(x,y) :- (-249.963,-211.832)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 223
# Estimated position(x,y) :- (-245.127,-214.327)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 224
# Estimated position(x,y) :- (-239.57,-213.853)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 225
# Estimated position(x,y) :- (-234.086,-219.148)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 226
# Estimated position(x,y) :- (-229.896,-219.959)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 227
# Estimated position(x,y) :- (-224.813,-224.463)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 228
# Estimated position(x,y) :- (-219.608,-229.993)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 229
# Estimated position(x,y) :- (-214.222,-234.551)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 230
# Estimated position(x,y) :- (-210.506,-236.916)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 231
# Estimated position(x,y) :- (-206.388,-239.324)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 232
# Estimated position(x,y) :- (-201.003,-239.726)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 233
# Estimated position(x,y) :- (-195.459,-242.629)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 234
# Estimated position(x,y) :- (-190.694,-240.682)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 235
# Estimated position(x,y) :- (-184.892,-243.646)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 236
# Estimated position(x,y) :- (-179.658,-247.287)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 237
# Estimated position(x,y) :- (-175.497,-250.865)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 238
# Estimated position(x,y) :- (-170.781,-250.28)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 239
# Estimated position(x,y) :- (-164.975,-254.666)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 240
# Estimated position(x,y) :- (-160.108,-255.573)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 241
# Estimated position(x,y) :- (-155.71,-259.04)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 242
# Estimated position(x,y) :- (-150.88,-259.285)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 243
# Estimated position(x,y) :- (-146.844,-259.009)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 244
# Estimated position(x,y) :- (-141.094,-261.366)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 245
# Estimated position(x,y) :- (-136.358,-262.221)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 246
# Estimated position(x,y) :- (-131.465,-266.313)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 247
# Estimated position(x,y) :- (-126.356,-265.098)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 248
# Estimated position(x,y) :- (-121.574,-265.714)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 249
# Estimated position(x,y) :- (-116.318,-266.847)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 250
# Estimated position(x,y) :- (-111.182,-268.898)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 251
# Estimated position(x,y) :- (-105.953,-269.009)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 252
# Estimated position(x,y) :- (-101.544,-269.416)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 253
# Estimated position(x,y) :- (-96.3911,-274.117)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 254
# Estimated position(x,y) :- (-91.2561,-272.798)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 255
# Estimated position(x,y) :- (-86.1566,-276.223)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 256
# Estimated position(x,y) :- (-81.3678,-273.3)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 257
# Estimated position(x,y) :- (-76.4171,-274.303)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 258
# Estimated position(x,y) :- (-71.4751,-277.48)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 259
# Estimated position(x,y) :- (-66.4518,-280.155)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 260
# Estimated position(x,y) :- (-61.3746,-279.137)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 261
# Estimated position(x,y) :- (-56.511,-279.431)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 262
# Estimated position(x,y) :- (-51.5358,-278.336)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 263
# Estimated position(x,y) :- (-46.7498,-277.364)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 264
# Estimated position(x,y) :- (-41.8686,-279.473)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 265
# Estimated position(x,y) :- (-36.9323,-279.921)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 266
# Estimated position(x,y) :- (-32.027,-282.773)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 267
# Estimated position(x,y) :- (-27.0372,-278.544)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 268
# Estimated position(x,y) :- (-22.1625,-278.87)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 269
# Estimated position(x,y) :- (-17.2226,-279.639)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 270
# Estimated position(x,y) :- (-12.3051,-277.033)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 271
# Estimated position(x,y) :- (-7.40918,-279.037)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 272
# Estimated position(x,y) :- (-2.52248,-280.318)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 273
# Estimated position(x,y) :- (2.37249,-282.951)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 274
# Estimated position(x,y) :- (7.22782,-281.61)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 275
# Estimated position(x,y) :- (12.2015,-281.486)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 276
# Estimated position(x,y) :- (17.1505,-277.687)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 277
# Estimated position(x,y) :- (22.0461,-277.236)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 278
# Estimated position(x,y) :- (26.9113,-277.814)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 279
# Estimated position(x,y) :- (31.812,-273.848)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 280
# Estimated position(x,y) :- (36.7038,-277.962)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 281
# Estimated position(x,y) :- (41.4573,-278.11)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 282
# Estimated position(x,y) :- (46.1518,-281.737)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 283
# Estimated position(x,y) :- (51.0281,-276.886)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 284
# Estimated position(x,y) :- (55.7494,-279.024)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 285
# Estimated position(x,y) :- (60.9523,-279.43)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 286
# Estimated position(x,y) :- (66.2097,-278.602)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 287
# Estimated position(x,y) :- (71.5478,-276.06)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 288
# Estimated position(x,y) :- (75.6801,-273.528)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 289
# Estimated position(x,y) :- (81.1318,-270.492)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 290
# Estimated position(x,y) :- (86.2106,-268.897)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 291
# Estimated position(x,y) :- (90.6103,-267.083)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 292
# Estimated position(x,y) :- (95.851,-267.949)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 293
# Estimated position(x,y) :- (100.461,-268.242)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 294
# Estimated position(x,y) :- (105.96,-265.454)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 295
# Estimated position(x,y) :- (110.852,-262.506)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 296
# Estimated position(x,y) :- (116.003,-263.317)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 297
# Estimated position(x,y) :- (121.189,-262.627)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 298
# Estimated position(x,y) :- (126.183,-260.412)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 299
# Estimated position(x,y) :- (130.702,-258.879)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 300
# Estimated position(x,y) :- (135.402,-258.222)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 301
# Estimated position(x,y) :- (140.662,-252.266)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 302
# Estimated position(x,y) :- (145.324,-253.646)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 303
# Estimated position(x,y) :- (149.509,-251.321)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 304
# Estimated position(x,y) :- (154.544,-252.527)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 305
# Estimated position(x,y) :- (159.606,-248.763)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 306
# Estimated position(x,y) :- (164.826,-246.495)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 307
# Estimated position(x,y) :- (169.694,-245.215)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 308
# Estimated position(x,y) :- (175.553,-243.935)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 309
# Estimated position(x,y) :- (181.314,-242.467)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 310
# Estimated position(x,y) :- (185.658,-237.361)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 311
# Estimated position(x,y) :- (189.015,-233.57)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 312
# Estimated position(x,y) :- (194.982,-231.495)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 313
# Estimated position(x,y) :- (198.762,-231.399)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 314
# Estimated position(x,y) :- (203.94,-228.036)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 315
# Estimated position(x,y) :- (209.621,-222.317)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 316
# Estimated position(x,y) :- (215.24,-221.172)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 317
# Estimated position(x,y) :- (220.688,-217.615)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 318
# Estimated position(x,y) :- (225.42,-217.068)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 319
# Estimated position(x,y) :- (230.857,-212.525)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 320
# Estimated position(x,y) :- (235.448,-209.477)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 321
# Estimated position(x,y) :- (240.105,-206.646)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 322
# Estimated position(x,y) :- (244.121,-203.569)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 323
# Estimated position(x,y) :- (248.461,-202.172)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 324
# Estimated position(x,y) :- (253.781,-198.108)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 325
# Estimated position(x,y) :- (257.286,-193.323)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 326
# Estimated position(x,y) :- (262.968,-189.341)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 327
# Estimated position(x,y) :- (266.221,-185.366)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 328
# Estimated position(x,y) :- (271.224,-182.288)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 329
# Estimated position(x,y) :- (276.421,-177.063)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 330
# Estimated position(x,y) :- (281.976,-171.938)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 331
# Estimated position(x,y) :- (286.803,-169.204)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 332
# Estimated position(x,y) :- (290.362,-163.396)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 333
# Estimated position(x,y) :- (295.602,-157.493)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 334
# Estimated position(x,y) :- (299.17,-153.238)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 335
# Estimated position(x,y) :- (304.2,-150.334)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 336
# Estimated position(x,y) :- (309.64,-144.665)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 337
# Estimated position(x,y) :- (313.004,-140.902)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 338
# Estimated position(x,y) :- (316.041,-135.342)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 339
# Estimated position(x,y) :- (320.91,-131.348)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 340
# Estimated position(x,y) :- (323.824,-126.265)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 341
# Estimated position(x,y) :- (329.39,-119.904)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 342
# Estimated position(x,y) :- (332.333,-113.674)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 343
# Estimated position(x,y) :- (335.882,-107.699)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 344
# Estimated position(x,y) :- (339.896,-104.006)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 345
# Estimated position(x,y) :- (342.412,-98.3074)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 346
# Estimated position(x,y) :- (343.835,-93.2425)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 347
# Estimated position(x,y) :- (346.468,-86.9466)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 348
# Estimated position(x,y) :- (350.696,-80.9124)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 349
# Estimated position(x,y) :- (352.703,-74.3232)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 350
# Estimated position(x,y) :- (355.713,-68.0255)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 351
# Estimated position(x,y) :- (357.583,-61.853)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 352
# Estimated position(x,y) :- (360.507,-55.5509)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 353
# Estimated position(x,y) :- (361.024,-49.128)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 354
# Estimated position(x,y) :- (362.857,-43.129)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 355
# Estimated position(x,y) :- (362.069,-37.114)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 356
# Estimated position(x,y) :- (363.601,-30.292)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 357
# Estimated position(x,y) :- (365.007,-24.1867)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 358
# Estimated position(x,y) :- (364.214,-17.9552)
# Uncertainity(x,y) :- (0.0630494,0.0413105)
#
# ---------------------------------
#
# Iteration :- 359
# Estimated position(x,y) :- (366.685,-11.424)
# Uncertainity(x,y) :- (0.0630494,0.0413105)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pred_state[p][0])
    br.append(est_state[p][0])
    m.append(pos[p][0])
# pred_state[2][0]
# plt.plot(i,ar,color='orange')
plt.plot(i,br,color='blue')
plt.plot(i,m,color='red')
plt.title("comparision of estimated x(blue) and measured x(red)")
plt.show()
# comparision of estimated x(blue) and measured x(red)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pred_state[p][3])
    br.append(est_state[p][3])
    m.append(pos[p][1])
# pred_state[2][0]
# plt.plot(i,ar,color='orange')
plt.plot(i,br,color='blue')
plt.plot(i,m,color='red')
plt.title("comparision of estimated y(blue) and measured y(red)")
plt.show()
# comparision of estimated y(blue) and measured y(red)

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(est_state[p][0])
    br.append(est_state[p][3])
    m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='blue')
plt.title("estimated trajectory")
plt.show()
# plt.plot(i,br)
# plt.plot(i,m)
# estimated trajectory

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
m=[]
for p in range(1,len(vel)):
    ar.append(pos[p][0])
    br.append(pos[p][1])
#     m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='red')
plt.title("measured trajectory")
plt.show()
# plt.plot(i,br)
# plt.plot(i,m)
# measured trajectory

# %%
i=np.arange(1,len(vel))
ar=[]
br=[]
ar1=[]
br1=[]
ar2=[]
br2=[]
m=[]
for p in range(1,len(vel)):
    ar.append(est_state[p][0])
    br.append(est_state[p][3])    
    ar1.append(pred_state[p][0])
    br1.append(pred_state[p][3])
    ar2.append(pos[p][0])
    br2.append(pos[p][1])    
#     m.append(pos[p][0])
# pred_state[2][0]
plt.plot(ar,br,color='blue')
# plt.plot(ar1,br1,color='orange')
plt.plot(ar2,br2,color='red')
plt.title("measured(red) and estimated(blue) trjectory")
# plt.plot(i,br)
# plt.plot(i,m)
# measured(red) and estimated(blue) trjectory
plt.show()
